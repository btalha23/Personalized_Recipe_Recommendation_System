# %%
# %pwd
# %matplotlib inline

# Import necessary libraries
# neccasary packages are loaded
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path
import zipfile
from IPython.display import display, Markdown
from ast import literal_eval
# import calendar
# from wordcloud import WordCloud
# import nltk
# nltk.download('brown')

import random

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

from keras_preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences

from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense

# %% [markdown]
# # **Dataset cleaning and processing**
# Lets start and load the dataset.
#
# Few words about it:
#
# The RecipeNLG dataset (Poznań University of Technology) is an expansion of the Recipe1M+ dataset, offering a significantly larger selection of recipes. Unlike its predecessor, this dataset does not prioritize linking cooking instructions with their corresponding images and instead emphasizes the recipe text, structure, and logic. This updated collection contains over one million newly preprocessed and deduplicated recipes, making it the largest publicly accessible dataset in its field.
#
# The data could be downloaded from Poznań University of Technology website.

# %%
dataset_path = "dataset/dataset_recipes.csv"
print(dataset_path)

df = pd.read_csv(dataset_path)
# df = pd.read_csv(Path("../input/recipenlg/dataset/full_dataset.csv"), 
#                  converters={"ingredients": literal_eval, "directions": literal_eval, "NER":literal_eval})
# Out:
# dataset/dataset_recipes.csv

# %% [markdown]
# ## **List of columns**

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'ingredients', 'directions', 'link', 'source',
#        'NER'],
#       dtype='object')

# %% [markdown]
# The dataset consists of 7 columns:
# - id (int): ID.
# - title (str): Title of the recipe.
# - ingredients (list of str): Ingredients.
# - directions (list of str): Instruction steps.
# - link (str): URL link.
# - source (ClassLabel): Origin of each recipe record, with possible value {"Gathered", "Recipes1M"}:
#     1. "Gathered" (0): Additional recipes gathered from multiple cooking web pages using automated scripts in a web scraping process.
#     2. "Recipes1M" (1): Recipes from the "Recipe1M+" dataset.

# %% [markdown]
# ## Column renaming

# %% [markdown]
# df.head(10)

# %%
df.rename(columns={'Unnamed: 0': 'ID','directions': 'procedure', 'title': 'name'},inplace=True, errors='raise')

# %% [markdown]
# ## Data structure

# %%
df.head()
# Out:
#    ID                   name  \
# 0   0    No-Bake Nut Cookies
# 1   1  Jewell Ball'S Chicken
# 2   2            Creamy Corn
# 3   3          Chicken Funny
# 4   4   Reeses Cups(Candy)
#
#                                          ingredients  \
# 0  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  ["1 small jar chipped beef, cut up", "4 boned ...
# 2  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4  ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                            procedure  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
#
#                                                  NER
# 0  ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1  ["beef", "chicken breasts", "cream of mushroom...
# 2  ["frozen corn", "cream cheese", "butter", "gar...
# 3  ["chicken", "chicken gravy", "cream of mushroo...
# 4  ["peanut butter", "graham cracker crumbs", "bu...

# %% [markdown]
# ## Setting the types

# %%
df = df.astype({'ID': int, 
                'name': str,
                'ingredients': 'object', 
                'procedure': 'object', 
                'link': str,
                'source': 'category', 
                'NER': 'object'})

# %% [markdown]
# ## **Adding extra columns**
# The variations in ingredients and their quantities across recipes, as well as the number of steps in each recipe, are of interest.

# %%
df['n_NER'] = df['NER'].apply(len)
df['n_procedures'] = df['procedure'].apply(len)

# %%
df.head()
# Out:
#    ID                   name  \
# 0   0    No-Bake Nut Cookies
# 1   1  Jewell Ball'S Chicken
# 2   2            Creamy Corn
# 3   3          Chicken Funny
# 4   4   Reeses Cups(Candy)
#
#                                          ingredients  \
# 0  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  ["1 small jar chipped beef, cut up", "4 boned ...
# 2  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4  ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                            procedure  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
#
#                                                  NER  n_NER  n_procedures
# 0  ["brown sugar", "milk", "vanilla", "nuts", "bu...     88           357
# 1  ["beef", "chicken breasts", "cream of mushroom...     67           175
# 2  ["frozen corn", "cream cheese", "butter", "gar...     76           171
# 3  ["chicken", "chicken gravy", "cream of mushroo...     73           394
# 4  ["peanut butter", "graham cracker crumbs", "bu...     89           229

# %% [markdown]
# ### **Cleaning empty**
# First lets copy the df

# %%
df_old = df[:]

# %% [markdown]
# #### Cleaning n_NER column

# %%
df = df[df['n_NER'] > 0]

# %% [markdown]
# #### Cleaning n_procedures column

# %%
df = df[df['n_procedures'] > 0]

# %%
# Display the first few rows of the dataset
print("Dataset Head:\n", df.head())

# Display basic information about the dataset
print("\nDataset Info:\n")
df.info()

# Display summary statistics of the dataset
print("\nDataset Description:\n", df.describe())

# Check for missing values
print("\nMissing Values:\n", df.isnull().sum())

# Check for duplicates
print("\nDuplicate Rows:\n", df.duplicated().sum())

# Visualize distribution of recipes
plt.figure(figsize=(10, 6))
sns.countplot(y=df['source'])
plt.title('Distribution of Recipes by Source')
plt.xlabel('Count')
plt.ylabel('Source')
plt.show()
# Out:
# Dataset Head:
#     ID                   name  \
# 0   0    No-Bake Nut Cookies
# 1   1  Jewell Ball'S Chicken
# 2   2            Creamy Corn
# 3   3          Chicken Funny
# 4   4   Reeses Cups(Candy)
#
#                                          ingredients  \
# 0  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  ["1 small jar chipped beef, cut up", "4 boned ...
# 2  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4  ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                            procedure  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
#
#                                                  NER  n_NER  n_procedures
# 0  ["brown sugar", "milk", "vanilla", "nuts", "bu...     88           357
# 1  ["beef", "chicken breasts", "cream of mushroom...     67           175
# 2  ["frozen corn", "cream cheese", "butter", "gar...     76           171
# 3  ["chicken", "chicken gravy", "cream of mushroo...     73           394
# 4  ["peanut butter", "graham cracker crumbs", "bu...     89           229
#
# Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2231142 entries, 0 to 2231141
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   ID            int32
#  1   name          object
#  2   ingredients   object
#  3   procedure     object
#  4   link          object
#  5   source        category
#  6   NER           object
#  7   n_NER         int64
#  8   n_procedures  int64
# dtypes: category(1), int32(1), int64(2), object(5)
# memory usage: 129.8+ MB
#
# Dataset Description:
#                   ID         n_NER  n_procedures
# count  2.231142e+06  2.231142e+06  2.231142e+06
# mean   1.115570e+06  1.117463e+02  5.051099e+02
# std    6.440754e+05  5.501059e+01  4.524093e+02
# min    0.000000e+00  2.000000e+00  5.000000e+00
# 25%    5.577852e+05  7.400000e+01  2.210000e+02
# 50%    1.115570e+06  1.020000e+02  3.710000e+02
# 75%    1.673356e+06  1.380000e+02  6.410000e+02
# max    2.231141e+06  5.597000e+03  1.497900e+04
#
# Missing Values:
#  ID              0
# name            0
# ingredients     0
# procedure       0
# link            0
# source          0
# NER             0
# n_NER           0
# n_procedures    0
# dtype: int64
#
# Duplicate Rows:
#  0

# %%
# Remove duplicate rows
df = df.drop_duplicates()

# Handling missing values
# For simplicity, we will drop rows with missing values. 
# Depending on the data, you may choose to impute missing values.
df = df.dropna()

# Verify that there are no more missing values or duplicates
print("\nMissing Values After Cleaning:\n", df.isnull().sum())
print("\nDuplicate Rows After Cleaning:\n", df.duplicated().sum())
# Out:
# Missing Values After Cleaning:
#  ID              0
# name            0
# ingredients     0
# procedure       0
# link            0
# source          0
# NER             0
# n_NER           0
# n_procedures    0
# dtype: int64
#
# Duplicate Rows After Cleaning:
#  0

# %% [markdown]
# ### Tokenize Ingredients and Procedures for NLP Models

# %%
# Tokenizing only the ingredients
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['NER'])  # Use the NER column only. NER column contains the ingredients
ingredient_sequences = tokenizer.texts_to_sequences(df['NER'])
print(f"ingredient_sequences -> {ingredient_sequences[0:5]}")

# Calculate the length of each ingredient list
sequence_lengths = [len(seq) for seq in ingredient_sequences]

# Set max_sequence_length to a suitable value, e.g., 90th percentile
max_sequence_length = int(np.percentile(sequence_lengths, 90))

ingredient_sequences_padded = pad_sequences(ingredient_sequences, maxlen=max_sequence_length)
# Out:
# ingredient_sequences -> [[28, 2, 12, 15, 64, 4, 951, 863, 180, 43, 491], [37, 17, 106, 9, 50, 94, 40, 42, 9], [79, 48, 9, 6, 4, 10, 19, 1, 3], [17, 17, 464, 9, 50, 94, 40, 180, 6], [100, 4, 165, 161, 85, 4, 84, 2, 35, 66]]

# %%
# len(ingredient_sequences)
# df['NER'].unique
# # ingredient_sequences[0:10]

# NER_exploded = df.explode('NER')
# print(f"NER_explode len {len(NER_exploded)}")
# ingredients = NER_exploded['NER']
# print(ingredients[0:10])
# # get the unique values of the exploded column
# unique_NER_values = NER_exploded['NER'].unique()
# print(len(unique_NER_values))

# %%
NER_exploded = df.explode('NER')
# print(f"NER_explode len {len(NER_exploded)}")

ingredients = NER_exploded['NER']
# print(ingredients[0:10])

# get the unique values of the exploded column
unique_NER_values = NER_exploded['NER'].unique()
# print(len(unique_NER_values))

# %%
# Assume df is your DataFrame containing the 'ingredients' column
# For demonstration purposes, let's create a sample DataFrame with unique ingredients
# In your case, replace this with your actual DataFrame
# df = pd.read_csv('your_dataset.csv')  # Load your dataset

# Create a sample ingredients list (replace this with actual unique ingredients)
ingredients_list = unique_NER_values.tolist()  # Replace this with df['ingredients'].unique()

# Function to generate random ingredient combinations
def generate_random_combinations(ingredients_list, num_combinations=50000, max_ingredients_per_combination=5):
    combinations = []
    for _ in range(num_combinations):
        # Randomly select between 1 and max_ingredients_per_combination ingredients
        num_ingredients = random.randint(1, max_ingredients_per_combination)
        combination = random.sample(ingredients_list, num_ingredients)
        combinations.append(', '.join(combination))  # Join selected ingredients into a string
    return combinations

# Generate 50,000 user input combinations
user_input_combinations = generate_random_combinations(ingredients_list, num_combinations=50000)

# Example: Print the first 10 combinations
for i in range(10):
    print(user_input_combinations[i])
# Out:
# ["eggs", "oil", "milk", "flour", "sugar", "salt", "poppy seed", "baking powder", "vanilla extract", "almond extract", "butter"]
# ["shrimp", "chicken stock", "butter", "okra", "onion", "green pepper", "clove garlic", "parsley", "thyme", "bay leaf", "tomatoes", "salt"], ["Hazelnut Cafe", "water", "accompaniments", "Chocolate", "'S ANGEL", "JET-PUFFED Miniature Marshmallows", "cinnamon sticks", "canes"], ["tomatoes", "garlic", "green peppers", "onions", "cooking oil", "tomato paste", "sugar", "salt", "basil", "oregano"], ["sugar", "cream cheese", "mashed ripe banana", "eggs", "baking mix", "walnuts", "Cooking spray"], ["No", "ground cinnamon", "honey", "vanilla", "yogurt", "splenda", "Lemon juice"]
# ["flour", "baking powder", "soda", "salt", "N", "shortening", "eggs", "nuts", "bananas"], ["goat cheese", "pinenuts", "tomatoes", "chicken", "I", "italian seasoned dry bread crumbs", "Vodka Sauce", "garlic", "pasta"], ["peeled apples", "eggs", "vanilla", "soda", "cinnamon", "nuts", "butter", "vanilla", "sugar", "oil", "flour", "salt", "nutmeg", "brown sugar", "milk"], ["pineapple", "mandarin oranges", "vanilla instant pudding"], ["cabbage", "onion", "squash", "zucchini", "corn", "green beans", "chicken", "shredded cheese", "salt", "black pepper", "paprika", "olive oil", "clove garlic"]
# ["ground pork", "hoisin sauce", "soy sauce", "five spice powder", "garlic", "ginger", "white vinegar", "peanut oil", "sesame oil", "brown sugar", "coleslaw mix", "bean sprouts", "mint", "snow peas", "red onion", "noodles"], ["white cake mix", "vanilla pudding", "strawberry"], ["wonton wrappers", "mushroom", "barbecue sauce", "black olives", "green pepper", "broccoli", "marinara sauce", "red onion", "soy mozzarella cheese", "bacon strips"]
# ["cucumbers", "head cabbage", "onions", "salt", "vinegar", "sugar", "dry mustard", "celery", "flour", "turmeric"], ["pearl barley", "white fungus", "lotus seeds", "longan Dried", "nuts Vacuum Packet", "dates", "Da Hai", "persimmon", "cane sugar", "knots of", "water"]
# ["butter", "sugar", "cream cheese", "flour", "eggs", "vanilla", "butternut flavor"], ["Ground Meat", "Chili Powder", "Onion", "clove of Garlic", "pepper", "Kidney Beans", "Tomatoes", "Tomato Paste", "Sweet Peppers", "Brown Sugar", "Vinegar", "Cumin", "Italian Seasoning", "Parsley", "Oregano", "Bay Leaves", "Water", "Sour Cream", "Chives", "Shredded Cheese", "butter"], ["ground beef", "chili powder", "green onions", "green pepper", "Worcestershire sauce", "tomato sauce", "Velveeta"], ["cabbage", "tomatoes", "onions", "celery", "green beans", "water", "beef"]
# ["chicken", "unsweetened coconut milk", "fish sauce", "red curry", "onion", "cornstarch", "cold water", "fresh basil"]
# ["blocks firm", "cornstarch", "flaxseed meal", "soymilk", "breadcrumbs", "all-purpose", "paprika", "sage", "garlic", "ginger", "onion powder", "ground black pepper"], ["chicken", "picante sauce", "green onion", "cumin", "oregano", "flour tortillas", "butter", "shredded cheese"], ["green cabbage", "red cabbage", "green bell pepper", "red bell pepper", "carrot", "low-fat mayonnaise", "nonfat yogurt", "cider vinegar", "balsamic vinegar", "mustard", "garlic", "celery salt", "ground black pepper", "Salt", "salt", "extra virgin olive oil"], ["Bonito", "Sake", "Soy sauce", "clove Garlic", "Ginger", "Katakuriko"]
# ["sour cream", "mayonnaise", "scallions", "dill", "lemon juice", "garlic powder", "red pepper", "lemon pepper", "salt", "Dipping Utensils", "snow", "wavy chips", "pita chips"]
# ["rice vinegar", "chili sauce", "light brown sugar", "mustard", "extra virgin olive oil", "salt", "sesame oil", "sesame seeds", "purple cabbage", "cabbage", "carrots", "fresh ginger", "peppers", "red onion", "buns", "ketchup", "Sriracha sauce", "tamari", "ginger", "rice vinegar", "yellow classic mustard"], ["hamburger", "potatoes", "carrots", "catsup", "onion"], ["egg whites", "sugar", "salt", "cream of tartar", "cold water", "white corn syrup", "vanilla"], ["gelatine", "tomato soup", "mayonnaise", "cream cheese", "salt", "sugar", "green pepper", "celery", "green onions", "tuna"]

# %%
user_input_combinations_dict = {'user_input_simulated': user_input_combinations}
df_user_input_sim = pd.DataFrame(user_input_combinations_dict)
df_user_input_sim.to_csv('user_input_simulated.csv', index=False)

df_check = pd.read_csv('user_input_simulated.csv')
df_check.head()
# Out:
#                                 user_input_simulated
# 0  ["eggs", "oil", "milk", "flour", "sugar", "sal...
# 1  ["shrimp", "chicken stock", "butter", "okra", ...
# 2  ["flour", "baking powder", "soda", "salt", "N"...
# 3  ["ground pork", "hoisin sauce", "soy sauce", "...
# 4  ["cucumbers", "head cabbage", "onions", "salt"...

# %%
embedding_dim = 300  # Size of the embedding vector
lstm_units = 128      # Number of LSTM units

model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=embedding_dim, input_length=max_sequence_length))
model.add(LSTM(lstm_units, return_sequences=False))
model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
# Out:
# C:\Users\batoo\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# string representation of list to list using ast.literal_eval()
import ast

print(f"NER -> {df['NER'].head(5)}")

# Convert the string representation of lists to actual lists
df['ingredients_list'] = df['NER'].apply(ast.literal_eval)
print(f"ingredients_list -> {df['ingredients_list'].head(5)}")

# Convert the ingredients to a single string for each recipe
df['ingredients_str'] = df['ingredients_list'].apply(lambda x: ' '.join(x))
print(f"ingredients_str -> {df['ingredients_str'].head(5)}")

# # Fit a TF-IDF Vectorizer on the ingredients
# tfidf = TfidfVectorizer()
# tfidf_matrix = tfidf.fit_transform(df['ingredients_str'])

# # Function to compute similarity scores
# def compute_similarity(user_ingredients, tfidf, tfidf_matrix):
#     user_tfidf = tfidf.transform([user_ingredients])
#     cosine_sim = cosine_similarity(user_tfidf, tfidf_matrix)
#     return cosine_sim.flatten()

# # # Example user ingredients
# # user_ingredients = "chicken garlic onion salt pepper"
# # similarity_scores = compute_similarity(user_ingredients, tfidf, tfidf_matrix)
# Out:
# NER -> 0    ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1    ["beef", "chicken breasts", "cream of mushroom...
# 2    ["frozen corn", "cream cheese", "butter", "gar...
# 3    ["chicken", "chicken gravy", "cream of mushroo...
# 4    ["peanut butter", "graham cracker crumbs", "bu...
# Name: NER, dtype: object
# ingredients_list -> 0    [brown sugar, milk, vanilla, nuts, butter, bit...
# 1    [beef, chicken breasts, cream of mushroom soup...
# 2    [frozen corn, cream cheese, butter, garlic pow...
# 3    [chicken, chicken gravy, cream of mushroom sou...
# 4    [peanut butter, graham cracker crumbs, butter,...
# Name: ingredients_list, dtype: object
# ingredients_str -> 0    brown sugar milk vanilla nuts butter bite size...
# 1    beef chicken breasts cream of mushroom soup so...
# 2    frozen corn cream cheese butter garlic powder ...
# 3    chicken chicken gravy cream of mushroom soup s...
# 4    peanut butter graham cracker crumbs butter pow...
# Name: ingredients_str, dtype: object

# %%
# Fit a TF-IDF Vectorizer on the ingredients
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(df['ingredients_str'])

# Function to compute similarity scores
def compute_similarity(user_ingredients, tfidf, tfidf_matrix):
    user_tfidf = tfidf.transform([user_ingredients])
    cosine_sim = cosine_similarity(user_tfidf, tfidf_matrix)
    return cosine_sim.flatten()

# Example user ingredients
user_ingredients = "chicken garlic onion salt pepper"
similarity_scores = compute_similarity(user_ingredients, tfidf, tfidf_matrix)

# %%
similarity_scores
# Out:
# array([0.        , 0.14644805, 0.31147986, ..., 0.03567376, 0.03907691,
#        0.12303516])

# %%
# # Example hardcoded user ingredients
# hardcoded_user_inputs = [
#     "chicken, garlic, onion, salt, pepper",
#     "beef, carrots, potatoes, salt, pepper",
#     "tofu, soy sauce, ginger, garlic, scallions"
# ]

df_user_input = pd.read_csv('user_input_simulated.csv')
# Iterate over the loaded data to preprocess and compute similarity scores
for index, row in df_user_input.iterrows():
    user_ingredients = row['user_input_simulated']
    user_ingredients_list = [ingredient.strip() for ingredient in user_ingredients.split(',')]
    user_ingredients_str = ' '.join(user_ingredients_list)
    print(user_ingredients_str)
    
    # Compute similarity scores
    similarity_scores = compute_similarity(user_ingredients_str, tfidf, tfidf_matrix)

    # Print the similarity scores
    print(similarity_scores)
# Out:
# ["eggs" "oil" "milk" "flour" "sugar" "salt" "poppy seed" "baking powder" "vanilla extract" "almond extract" "butter"]
# [0.0821587  0.         0.11540357 ... 0.03237508 0.04219306 0.02588085]
# ["shrimp" "chicken stock" "butter" "okra" "onion" "green pepper" "clove garlic" "parsley" "thyme" "bay leaf" "tomatoes" "salt"] ["Hazelnut Cafe" "water" "accompaniments" "Chocolate" "'S ANGEL" "JET-PUFFED Miniature Marshmallows" "cinnamon sticks" "canes"] ["tomatoes" "garlic" "green peppers" "onions" "cooking oil" "tomato paste" "sugar" "salt" "basil" "oregano"] ["sugar" "cream cheese" "mashed ripe banana" "eggs" "baking mix" "walnuts" "Cooking spray"] ["No" "ground cinnamon" "honey" "vanilla" "yogurt" "splenda" "Lemon juice"]
# [0.02864422 0.04484586 0.11220719 ... 0.01751095 0.07164775 0.12105833]
# ["flour" "baking powder" "soda" "salt" "N" "shortening" "eggs" "nuts" "bananas"] ["goat cheese" "pinenuts" "tomatoes" "chicken" "I" "italian seasoned dry bread crumbs" "Vodka Sauce" "garlic" "pasta"] ["peeled apples" "eggs" "vanilla" "soda" "cinnamon" "nuts" "butter" "vanilla" "sugar" "oil" "flour" "salt" "nutmeg" "brown sugar" "milk"] ["pineapple" "mandarin oranges" "vanilla instant pudding"] ["cabbage" "onion" "squash" "zucchini" "corn" "green beans" "chicken" "shredded cheese" "salt" "black pepper" "paprika" "olive oil" "clove garlic"]
# [0.18983458 0.04379646 0.21497268 ... 0.05167836 0.0730968  0.11020602]
# ["ground pork" "hoisin sauce" "soy sauce" "five spice powder" "garlic" "ginger" "white vinegar" "peanut oil" "sesame oil" "brown sugar" "coleslaw mix" "bean sprouts" "mint" "snow peas" "red onion" "noodles"] ["white cake mix" "vanilla pudding" "strawberry"] ["wonton wrappers" "mushroom" "barbecue sauce" "black olives" "green pepper" "broccoli" "marinara sauce" "red onion" "soy mozzarella cheese" "bacon strips"]
# [0.03443286 0.04503048 0.08007561 ... 0.26425625 0.05898555 0.09594823]
# ["cucumbers" "head cabbage" "onions" "salt" "vinegar" "sugar" "dry mustard" "celery" "flour" "turmeric"] ["pearl barley" "white fungus" "lotus seeds" "longan Dried" "nuts Vacuum Packet" "dates" "Da Hai" "persimmon" "cane sugar" "knots of" "water"]
# [0.03482208 0.03221988 0.00803424 ... 0.05653149 0.07279074 0.00317354]
# ["butter" "sugar" "cream cheese" "flour" "eggs" "vanilla" "butternut flavor"] ["Ground Meat" "Chili Powder" "Onion" "clove of Garlic" "pepper" "Kidney Beans" "Tomatoes" "Tomato Paste" "Sweet Peppers" "Brown Sugar" "Vinegar" "Cumin" "Italian Seasoning" "Parsley" "Oregano" "Bay Leaves" "Water" "Sour Cream" "Chives" "Shredded Cheese" "butter"] ["ground beef" "chili powder" "green onions" "green pepper" "Worcestershire sauce" "tomato sauce" "Velveeta"] ["cabbage" "tomatoes" "onions" "celery" "green beans" "water" "beef"]
# [0.10790578 0.19958591 0.22566455 ... 0.03325437 0.08766043 0.18162406]
# ["chicken" "unsweetened coconut milk" "fish sauce" "red curry" "onion" "cornstarch" "cold water" "fresh basil"]
# [0.02600817 0.05218881 0.         ... 0.03873088 0.01153617 0.07561253]
# ["blocks firm" "cornstarch" "flaxseed meal" "soymilk" "breadcrumbs" "all-purpose" "paprika" "sage" "garlic" "ginger" "onion powder" "ground black pepper"] ["chicken" "picante sauce" "green onion" "cumin" "oregano" "flour tortillas" "butter" "shredded cheese"] ["green cabbage" "red cabbage" "green bell pepper" "red bell pepper" "carrot" "low-fat mayonnaise" "nonfat yogurt" "cider vinegar" "balsamic vinegar" "mustard" "garlic" "celery salt" "ground black pepper" "Salt" "salt" "extra virgin olive oil"] ["Bonito" "Sake" "Soy sauce" "clove Garlic" "Ginger" "Katakuriko"]
# [0.04570783 0.01820153 0.18265777 ... 0.07558603 0.12484467 0.11250835]
# ["sour cream" "mayonnaise" "scallions" "dill" "lemon juice" "garlic powder" "red pepper" "lemon pepper" "salt" "Dipping Utensils" "snow" "wavy chips" "pita chips"]
# [0.         0.08224625 0.14542014 ... 0.00690517 0.01825793 0.04845861]
# ["rice vinegar" "chili sauce" "light brown sugar" "mustard" "extra virgin olive oil" "salt" "sesame oil" "sesame seeds" "purple cabbage" "cabbage" "carrots" "fresh ginger" "peppers" "red onion" "buns" "ketchup" "Sriracha sauce" "tamari" "ginger" "rice vinegar" "yellow classic mustard"] ["hamburger" "potatoes" "carrots" "catsup" "onion"] ["egg whites" "sugar" "salt" "cream of tartar" "cold water" "white corn syrup" "vanilla"] ["gelatine" "tomato soup" "mayonnaise" "cream cheese" "salt" "sugar" "green pepper" "celery" "green onions" "tuna"]
# [0.08568465 0.11962476 0.13718762 ... 0.27443543 0.14592796 0.12445745]
# ["tentacles" "fish sauce" "freshly squeezed lime juice" "green onions" "salt" "freshly ground pepper" "butter" "fresh cilantro" "fresh Thai" "carrot" "chile sauce" "vegetable oil"] ["Rolos" "Pecan Halves" "Butter"] ["eggs" "sugar" "salt" "vanilla" "flour" "ground anise" "cold water"] ["milk chocolate" "chocolate" "butter" "eggs" "muscovado sugar" "flour"]
# [0.06458696 0.         0.08923605 ... 0.05616167 0.08801713 0.12152919]
# ["pumpkin" "salad oil" "sugar" "eggs" "flour" "baking powder" "baking soda" "clove powder" "cinnamon" "nutmeg" "salt"] ["seedless raspberry jam" "black raspberry liqueur" "orange juice" "containers mascarpone cheese" "heavy cream" "sugar" "vanilla" "fresh raspberries"]
# [0.03307    0.03998771 0.13784768 ... 0.0198591  0.07019569 0.01440955]
# ["pineapple" "pineapple" "carrots" "sugar" "flour" "Cheddar cheese" "margarine" "crackers"]
# [0.01764189 0.         0.05346867 ... 0.         0.01917978 0.02112023]
# ["sugar" "milk" "Marshmallow Creme" "butter" "peanut butter" "vanilla"] ["Batch" "Maple" "Eggs" "Salt" "Cheddar Cheese"] ["red" "kosher salt" "lemon zest" "lemon juice" "Sherry vinegar" "extra-virgin olive oil" "Freshly ground black pepper" "flat-leaf parsley" "walnuts" "fresh basil"]
# [0.06598026 0.         0.12257892 ... 0.02893979 0.09203282 0.2178736 ]
# ["pecans" "Ponzu sauce" "balsamic vinegar"] ["green beans" "wax beans" "kidney beans" "garbanzo beans" "green pepper" "olives" "green onion" "parsley" "pimiento" "sugar" "wine vinegar" "vegetable oil" "salt" "dry mustard" "pepper" "red pepper" "garlic"] ["beans" "water" "lean ham" "salt pork" "onion" "chorizo" "turnip greens" "potatoes"]
# [0.00595361 0.         0.08862836 ... 0.03594179 0.07796146 0.05792014]
# ["apples" "sugar" "cinnamon" "margarine" "sugar" "flour" "egg" "nuts" "salt"] ["shortening" "cane syrup" "eggs" "flour" "baking soda" "salt" "cocoa" "milk" "vanilla"] ["powdered sugar" "water"] ["cacao" "brandy" "milk" "Orange twists"]
# [0.12354997 0.         0.02824898 ... 0.01629319 0.12719839 0.054906  ]
# ["choy" "carrots" "green onions" "teriyaki sauce"] ["lean ground beef" "onion" "garlic" "tomatoes" "oregano" "salt" "pepper" "spinach" "egg noodles" "Cheddar cheese"] ["tuna" "eggs" "mayonnaise" "pickles relish" "salt" "pepper"] ["water" "cinnamon sticks" "cloves" "lemons" "oranges" "sugar"] ["cooking apples" "water" "sugar" "brown sugar" "salt" "flour" "butter" "nutmeg" "cinnamon"]
# [0.05398093 0.03969186 0.14454125 ... 0.03991196 0.10271423 0.08971298]
# ["crescent rolls" "sour cream" "horseradish" "salt" "pepper" "mushrooms" "tomatoes" "broccoli" "peppers" "onions"] ["pineapple" "mini-marshmallows" "nuts"] ["egg whites" "sugar" "salt" "vanilla" "chocolate chips" "pecans" "Rice Krispies" "coconut"] ["butter" "onion" "peas" "carrots" "zucchini" "potatoes" "fresh parsley" "flour" "milk" "chicken"] ["onions" "italian plum" "garlic" "salt" "orange zest" "salmon" "orange juice" "olive oil" "white wine" "basil"]
# [0.10269736 0.09789987 0.11617316 ... 0.05163737 0.08455047 0.08927641]
# ["white" "peanut butter" "red"] ["Manila clams" "Water" "Japanese leeks"] ["lard" "sugar" "almond extract" "all-purpose" "egg yolk" "water" "blanched almond"] ["butter" "sugar" "eggs" "molasses" "soda" "baking powder" "buttermilk" "all-purpose" "cinnamon" "ginger" "vanilla" "nuts" "raisins"]
# [0.08066312 0.         0.07012096 ... 0.02243204 0.1145416  0.0279627 ]
# ["canola oil" "baby red potatoes" "curry" "red chiles" "mustard seeds" "cumin seeds" "ginger" "garlic" "turmeric" "kosher salt" "fresh cilantro" "mint leaves" "lime" "cayenne pepper"] ["apples" "flour" "sugar" "raisins" "cinnamon" "oatmeal" "butter" "brown sugar"] ["Canola oil" "yellow onion" "ground turkey meat" "ground cumin" "Kosher salt" "corn tortillas" "cheddar cheese" "romaine lettuce" "tomatoes" "Sour cream"] ["beef" "potatoes" "salt" "pepper" "wine vinegar" "vegetable oil" "tarragon" "parsley" "eggs" "tomatoes"] ["heads lettuce" "celery" "green onion" "chicken" "sesame seed" "almonds" "rice sticks"]
# [0.05294258 0.1019154  0.16104237 ... 0.18612594 0.22105403 0.07251499]
# ["pretzels" "sugar" "cold butter" "condensed milk" "lime juice" "lime zest" "topping" "fresh fruit"]
# [0.05282204 0.         0.03364629 ... 0.         0.01285308 0.01751077]
# ["cake mix" "mandarin oranges" "Wesson oil" "eggs" "vanilla pudding" "pineapple"] ["Chicken" "white wine vinegar" "extra-virgin olive oil" "garlic" "paprika" "ground cumin" "lemon juice" "salt" "ground black pepper" "chile powder" "onions" "skinless" "Rice" "chicken broth" "basmati rice" "garlic" "extra-virgin olive oil" "ground cumin" "cilantro" "salt" "ground black pepper" "frozen peas"] ["ground beef" "onion" "salt" "chili powder" "tomatoes" "kernel corn" "tomato sauce"] ["butter" "garlic" "flour" "chicken stock" "Cayenne pepper" "Salt"] ["Olive oil" "tomatoes" "onion" "chiles" "fresh jalape\u00f1o" "lime juice" "salt" "black pepper" "fresh cilantro" "Accompaniment"]
# [0.05250915 0.07530084 0.27483513 ... 0.07787888 0.10193953 0.12621948]
# ["Bacon" "Fennel" "Mayonnaise" "Cilantro" "Lemon Juice" "Salmon" "Olive Oil" "Salt" "Sandwich Rolls" ": Lettuce"] ["frozen peas" "celery" "onions" "mayonnaise" "pepper" "stuffing" "butter"] ["sugar" "water" "marshmallow cream" "vanilla" "nuts" "salt"] ["water" "yeast" "sugar" "salt" "egg" "flour" "soft shortening"]
# [0.08404415 0.04154654 0.19381912 ... 0.03526312 0.06975679 0.04068653]
# ["eggs" "sugar" "white rum" "flour" "baking powder" "coconut flakes" "butter" "mascarpone cheese" "powdered sugar" "pineapple juice" "pineapple" "lime juiced" "cake decorations"] ["shrimp" "scallions" "bacon"]
# [0.03063283 0.         0.0941794  ... 0.0290254  0.01911944 0.01089823]
# ["grits" "Bay seasoning" "salt" "Parmesan cheese" "Cooking oil" "butter" "tomatoes" "butter" "onion" "capers" "parsley" "lemon juice"] ["cheese" "English cheese" "Philadelphia cream cheese" "onion" "garlic" "Worcestershire sauce"]
# [0.02681117 0.04903568 0.25132811 ... 0.0506554  0.05892741 0.08378863]
# ["butter" "sugar" "vanilla" "salt" "all-purpose" "cinnamon sugar topping"] ["chocolate cake" "margarine" "milk" "chocolate chips" "caramels" "walnuts"] ["eggnoodles" "cream of mushroom soup" "peas" "tuna"] ["celery" "onion" "bread crumbs" "sausage" "egg" "salt" "grated cheese"] ["sandwich buns" "Singles" "tomato" "bacon"]
# [0.05223531 0.17695286 0.08640151 ... 0.01259337 0.07445593 0.2058263 ]
# ["olive oil" "corn" "chipotle powder" "avocado" "fresh cilantro" "green onions" "serrano pepper" "quinoa" "cherry tomatoes" "salt"]
# [0.         0.         0.21090607 ... 0.03067388 0.02704923 0.02134079]
# ["clams" "cream cheese" "salt" "onion" "Tabasco sauce" "garlic salt"] ["granulated sugar" "cinnamon" "margarine" "buttermilk"] ["Japanese eggplant" "each mustard" "soy sauce" "extra-long" "furikake" "sriracha"] ["margarine" "marshmallows" "vanilla flavoring" "Rice Krispies"] ["baby back pork" "Honey"]
# [0.04814915 0.03434383 0.08748539 ... 0.08602804 0.08890952 0.05073785]
# ["potato" "egg" "carrot" "olive oil" "salt" "broccoli"] ["garlic" "shallots" "cooking oil" "pork" "salt" "ground black pepper" "chicken broth" "soy sauce" "cream"] ["beets" "cauliflower" "onion" "olive oil" "salt" "pepper" "vegetable broth"]
# [0.         0.08308076 0.16321795 ... 0.14979843 0.17329835 0.10383757]
# ["margarine" "English cheese" "crab" "amount green pepper" "dinner rolls"]
# [0.         0.         0.0746942  ... 0.         0.00797158 0.02950436]
# ["box wheat" "cereal" "chedder cheese crackers" "peanuts" "canola oil" "hot sauce" "cajun seasoning" "garlic"] ["sugar" "marshmallow" "peanut butter" "Parkay" "chocolate" "block wax"]
# [0.01871859 0.         0.07116181 ... 0.03386601 0.01770372 0.03433517]
# ["extra lean ground beef" "onion" "garlic" "green pepper" "water" "ketchup" "Worcestershire sauce" "brown sugar" "mustard" "salt" "ground black pepper" "water" "cayenne pepper"] ["Sugar" "Red food coloring" "cranberry juice" "Sparkling cider" "Maraschino cherries"] ["bread" "beef" "monterey" "green chilis" "mayonnaise" "butter" "salt"]
# [0.04715776 0.08055457 0.13363195 ... 0.03380254 0.13722526 0.12143974]
# ["yellow cake mix" "milk" "cream of coconut" "Dream Whip"] ["whole wheat penne pasta" "lean ground beef" "onion" "salt" "dill" "mustard" "ketchup" "salt" "cheddar cheese" "green onions"]
# [0.01768998 0.16123002 0.0925648  ... 0.01729379 0.05728222 0.05290581]
# ["Rotisserie Chicken" "Beans" "Sour Cream" "Cheddar Cheese" "Cream Of Chicken Soup"] ["crumbled cornbread" "salt" "white pepper" "black pepper" "cayenne pepper" "onion powder" "oregano" "thyme" "basil" "bay leaves" "onion" "green onion" "parsley" "red bell pepper" "pepper" "garlic" "butter" "chicken broth" "milk" "egg"] ["Olive Oil" "Onion" "Garlic" "Flour" "Salt" "Tomatoes" "Carrots" "Red Wine" "Beef" "Brown Sugar"] ["zucchini" "ground chuck" "garlic powder" "onion" "tomato sauce" "salt" "oregano" "basil" "cheese" "egg" "parsley" "bread crumbs" "Mozzarella" "Parmesan"]
# [0.03994202 0.24866234 0.30532826 ... 0.05775795 0.11601207 0.22448443]
# ["Dates" "Bacon"] ["flour" "butter" "baking powder" "salt" "cinnamon" "egg" "orange juice" "walnuts" "dark raisins"] ["Butter" "eggs" "salt" "Garlic" "salmon" "Chives"] ["peanuts" "torn leaf lettuce" "cucumber" "tomato" "raisins" "celery" "torn romaine lettuce" "carrot" "onion" "Cheddar cheese" "mayonnaise" "parsley flakes" "plain yogurt" "mustard" "paprika" "ground red pepper" "black pepper" "pita rounds"]
# [0.01682216 0.         0.15430033 ... 0.01083387 0.07297866 0.13615396]
# ["unsalted butter" "bread" "milk" "chocolate" "sugar" "eggs" "egg yolks" "raisins" "ground cinnamon" "Powdered sugar"] ["tomatoes" "garlic" "sugar" "celery" "Parmesan cheese" "ground beef" "sweet onion" "mushrooms" "fresh pasta" "salt"] ["hamburger meat" "chili" "Ro-Tel" "Velveeta cheese"]
# [0.05618767 0.04819025 0.1234876  ... 0.00801401 0.07922449 0.12629125]
# ["heavy cream" "sour cream" "Potatos" "fingerling potatos" "kosher salt" "afford" "creme fraiche" "chives"] ["sugar" "water" "light corn syrup" "cream of tartar" "heavy whipping cream" "butter" "coarse kosher salt" "vanilla" "bittersweet chocolate" "milk" "cocoa" "sugar" "light corn syrup" "egg yolks" "cornstarch" "chilled heavy whipping cream" "coarse kosher salt"] ["lasagna" "cream-style cottage cheese" "cream cheese" "Mozzarella cheese" "Parmesan cheese" "Italian seasoning" "ground beef" "clove garlic" "sauce" "Mozzarella cheese" "Parmesan cheese"] ["tomatoes" "culatello salami" "bucatini pasta" "olive oil" "tomato sauce" "onion" "water" "grated cheese"]
# [0.02760752 0.19619943 0.26918824 ... 0.03632075 0.09798176 0.11885188]
# ["boil lasagna noodles" "Ricotta cheese" "Mozzarella cheese" "spinach" "cream of mushroom soup"]
# [0.         0.31591327 0.12011516 ... 0.         0.00939301 0.0306177 ]
# ["cookies" "butter" "vanilla ice cream" "Syrup" "Spanish peanuts"] ["Chicken" "ground chicken" "butter" "butter" "flour" "milk" "eggs" "pepper" "freshly ground nutmeg" "Red Pepper" "red bell peppers" "butter" "garlic" "anchovy paste" "extra virgin olive oil" "heavy cream"] ["water" "sugar" "orange juice" "frozen lemonade" "brandy"] ["cucumber" "heavy whipping cream whipped" "cream cheese"] ["dark molasses" "catsup" "onions" "orange" "orange juice" "vinegar" "oil" "steak sauce" "butter" "mustard" "Worcestershire sauce" "garlic" "salt" "black pepper" "Tabasco sauce" "cloves"]
# [0.06379305 0.14758409 0.30494804 ... 0.06575944 0.16618205 0.16798019]
# ["Chicken" "Pan" "Butter" "Flour" "clove Garlic" "Chicken Broth" "Frozen Vegetables" "Fresh Herbs" "Salt" "Heavy Cream" "Pie Crust" "Egg"] ["Crust" "Crackers" "Salt" "Brown Sugar" "Coconut Oil" "Cream Filling" "Fat Coconut Milk" "Lime Zest" "Lime Juice" "Powdered Sugar" "Vanilla" "Strawberries" "Sugar" "Lime Juice"]
# [0.07875616 0.12187692 0.18111125 ... 0.02379463 0.06634282 0.04145324]
# ["chili sauce" "brown sugar" "water" "fish sauce" "fresh ginger" "red pepper" "noodles" "vegetable oil" "eggs" "garlic" "fresh bean sprout" "green onion" "fresh cilantro" "peanuts" "lime wedges"]
# [0.03609882 0.         0.05806708 ... 0.06567106 0.02904244 0.0765774 ]
# ["cake mix" "solid-pack pumpkin" "water" "eggs" "vegetable oil" "vanilla" "butter" "nut flavoring" "apple cider" "apple cider" "cloves" "cinnamon" "cornstarch" "caramel ice cream topping"] ["potatoes" "sugar" "ground cinnamon" "vanilla extract" "ground ginger" "ground nutmeg" "milk" "eggs" "crust" "whipped cream"]
# [0.05852767 0.06939717 0.06473527 ... 0.01112313 0.22085945 0.04289157]
# ["tomatoes" "cucumber" "green bell pepper" "red onion" "red wine vinegar" "balsamic vinegar" "extra virgin olive oil" "salt" "fresh oregano" "kalamata olive" "feta cheese"] ["sugar" "milk" "butter" "vanilla" "salt" "peanut butter"] ["roll" "cream cheese" "sugar" "vanilla" "orange marmalade" "water"] ["flour" "flour" "white sugar" "chilled lightly" "egg yolks"] ["chicken breasts" "onion" "thyme" "rosemary" "garlic" "honey" "balsamic vinegar" "chicken stock" "olive oil" "butter"]
# [0.08038129 0.12553358 0.1622615  ... 0.04979721 0.0786408  0.08188084]
# ["chicken" "ground saffron" "olive oil" "Arborio rice" "Salt" "eggplants" "garlic" "mint" "basil" "egg yolk" "extra-virgin olive oil" "tomato sauce" "sugar" "Salt" "water"] ["sausage" "bell pepper" "purple onion" "pineapple" "sour sauce" "Tabasco sauce" "fresh jalapeno"]
# [0.04034294 0.07526044 0.07619828 ... 0.1076242  0.07136575 0.19171123]
# ["shortening" "butter" "brown sugar" "eggs" "flour" "pecans"] ["hazelnuts" "chocolate" "egg yolks" "sugar" "liqueur" "egg whites" "whipped cream" "chocolate sauce"] ["bananas" "cranberry sauce" "pineapple" "mayonnaise" "nuts" "light dairy whipped topping"] ["Bisquick" "Baking powder" "Vegetable oil" "Vanilla" "Sugar" "Milk" "Eggs" "Bananas" "Cream Cheese" "Butter/ Margarine" "Powdered Sugar" "vanilla"] ["flour" "cocoa" "baking powder" "baking soda" "salt" "cinnamon" "vegetable oil" "sugar" "eggs" "vanilla" "ground zucchini" "nuts" "milk"]
# [0.16992369 0.05703532 0.14763022 ... 0.05389829 0.07597424 0.10856967]
# ["olive oil" "soy sauce" "white wine" "sesame seeds" "sugar" "ground ginger" "ground black pepper" "green onions"] ["chicken" "onion" "Salt" "butter" "sour cream"] ["ground beef" "sweet Italian sausage" "onion" "garlic" "Italian-style tomatoes" "beef broth" "tomato juice" "salt" "basil" "oregano" "bay leaf" "fresh pepper" "fresh parsley" "frozen peas" "olives" "parmesan cheese"] ["lemon gelatin" "vanilla instant pudding" "boiling water" "frozen whipped topping"]
# [0.03027145 0.16604724 0.27511286 ... 0.24173617 0.13321691 0.18750198]
# ["beef brisket" "onion" "ketchup" "chili sauce" "brown sugar" "garlic" "beer"] ["vanilla wafer" "cake" "vanilla pudding" "milk" "light whipped topping" "strawberry" "walnuts"] ["crab meat" "bread crumbs" "Bay seasoning" "dry mustard" "egg" "black pepper" "mayonaise" "Worstershire sauce" "fresh parsley" "red bell pepper" "scallion" "vegetable oil" "lemon"] ["frozen hash browns" "butter" "salt" "onion" "sour cream" "cream of chicken soup" "Cheddar cheese"] ["salmon" "onion" "crackers" "eggs" "flour"]
# [0.06616776 0.2134856  0.1927372  ... 0.04610484 0.08441968 0.12582686]
# ["bran cereal" "chiles" "apple sauce" "flour" "salt" "baking soda" "honey" "milk" "eggs" "chocolate chips" "brown sugar" "cinnamon"] ["extra lean ground beef" "brown rice" "cabbage" "pasta sauce"] ["beef" "onion soup" "wine" "mushroom soup"]
# [0.11043191 0.26882766 0.01366454 ... 0.05590363 0.09323731 0.06497925]
# ["sweet potatoes" "olive oil" "salt"] ["cream cheese" "craisins" "walnuts" "assorted cracker"]
# [0.         0.06650651 0.10504835 ... 0.03302914 0.0305599  0.02396558]
# ["chicken" "drawn butter" "clove garlic" "sage" "flour" "salt" "pepper" "white wine"] ["salt" "sugar" "vinegar" "water" "color"] ["stuffing mix" "water" "ground beef" "whole kernel corn" "black olives" "onion flakes" "chili" "Cheddar"] ["coconut milk" "water" "cornstarch" "sugar"]
# [0.04111937 0.07083589 0.15824375 ... 0.03939245 0.06308353 0.05264989]
# ["flour" "rolled oats" "baking powder" "baking soda" "butter" "white sugar" "brown sugar" "egg" "vanilla"]
# [0.134018   0.         0.11784829 ... 0.0513687  0.05146621 0.03158307]
# ["water" "broccoli" "mushrooms" "butter" "nonfat dry milk powder" "Cheddar cheese soup" "hot sauce" "ground black pepper" "garlic powder"]
# [0.0436027  0.08013042 0.2916506  ... 0.03691473 0.05704152 0.1163118 ]
# ["cream cheese" "milk" "ReaLemon juice" "graham cracker crust" "fruit topping"] ["butter" "white syrup" "vanilla extract" "salt" "powdered sugar" "coconut flakes" "cinnamon"] ["butter" "mushrooms" "green onions" "all-purpose" "vegetable broth" "paprika" "salt" "black pepper"] ["extra lean ground beef" "tomato paste" "onion" "green pepper" "red pepper" "fresh tomato" "mustard" "ground black pepper" "hot pepper" "garlic" "stalks scallions" "ground ginger" "ground nutmeg" "orange rind" "thyme" "breadcrumbs"] ["celery" "green bell pepper" "green peas" "green onions" "sour cream" "mayo" "sugar" "Parmesan cheese" "bacon bits"]
# [0.04444976 0.10653293 0.21278634 ... 0.02539665 0.13392703 0.19444219]
# ["whole almonds" "sugar" "flour" "salt" "butter" "Cognac" "vanilla" "egg whites" "raspberries" "cream"]
# [0.06880421 0.07644009 0.11493989 ... 0.01345849 0.0587382  0.11980036]
# ["water" "beans" "chicken pieces" "tomato juice" "celery" "carrot" "onion" "garlic" "bay leaf" "instant beef bouillon" "basil" "oregano" "sage" "paprika"] ["CHOCOLATE CRUMB" "Flour" "Cornstarch" "Sugar" "Double-dutch" "Kosher Salt" "Unsalted Butter" "Unsalted Butter" "Sugar" "Syrup" "Egg" "Vanilla" "Baking Chocolate" "Flour" "Double-dutch" "Baking Powder" "\u00bc" "Kosher Salt" "Chocolate"] ["red wine" "concentrate" "lemon" "lime" "orange" "bing cherry" "brandy" "lemon-lime beverage"]
# [0.03538676 0.04588971 0.08421199 ... 0.0090705  0.11250065 0.08798807]
# ["clams" "all-purpose" "baking powder" "salt" "paprika" "pepper" "onion" "egg"] ["red bell pepper" "green onions" "nuts" "sesame oil" "pineapple tidbits" "Dressing" "sesame oil" "soy sauce" "rice vinegar" "sugar" "pineapple juice"]
# [0.08742734 0.         0.10953862 ... 0.38174013 0.11374989 0.07986438]
# ["white cake" "vanilla instant pudding" "eggs" "sour cream" "vegetable oil" "chocolate chips" "brown sugar" "Grape-nuts" "ground cinnamon"] ["cornbread mix" "cornbread mix" "egg" "milk" "salad dressing" "milk" "mayonnaise" "whole kernel corn" "green peppers" "Cheddar cheese" "celery" "green onions" "tomatoes" "ham"] ["corn tortillas" "shredded cheese" "tomatoes"] ["butter" "olive oil" "green onions" "garlic" "lemon" "chicken breasts" "salt" "pepper" "fresh parsley" "tomato" "buttered noodles"] ["applesauce" "eggs" "sugar" "brown sugar" "flour" "butter" "raisins" "cinnamon"]
# [0.16713142 0.12735114 0.21829764 ... 0.04130894 0.06777102 0.09950759]
# ["Bacon" "Sour Cream" "Mayonnaise" "weight Cream Cheese" "Freshly Ground Black Pepper" "Cheddar Cheese" "Green Onions"] ["Ingredients" "walnuts" "non-fat yogurt" "light mayonnaise" "parsley" "honey" "lemon" "ground black pepper" "crisp apples" "celery" "golden raisins" "lemon" "Boston lettuce"] ["margarine" "sweet onion" "'S" "Cheddar Cheese" "Bacon" "ground black pepper" "ground red pepper" "green onions"] ["ground beef" "salsa" "pinto beans" "onion" "cream of mushroom soup" "Velveeta cheese"] ["Chops" "Onions" "Potatoes" "Campbell's Golden Mushroom" "Milk" "Salt"]
# [0.00889561 0.263339   0.17319408 ... 0.00434819 0.10942331 0.12567467]
# ["Sugar" "Butter" "Flour" "Baking Soda" "Salt" "eggs" "Sour Cream" "Vanilla" "Lemon"]
# [0.10811527 0.25188948 0.18061041 ... 0.02114796 0.06597489 0.01448319]
# ["cocoa" "peanut butter" "Splenda"] ["chicken ramen noodles" "fresh asparagus" "sweet red pepper" "olive oil" "green onions" "garlic" "lime juice" "soy sauce" "sesame oil" "hot pepper"] ["vegetable oil" "summer" "onion" "eggs" "milk" "Cheddar cheese" "white sugar" "flour" "salt" "ground black pepper" "butter"] ["king prawns" "ground pork" "ginger" "garlic" "fresh cilantro" "sugar" "stalks lemongrass" "fish sauce" "lime juice +" "honey"]
# [0.041515   0.02294895 0.15901073 ... 0.21768573 0.10276443 0.11471325]
# ["shortening" "white sugar" "egg" "vanilla" "milk" "flour" "cocoa" "salt" "sprinkles"] ["rice noodles" "soy sauce" "orange juice" "orange zest" "sugar" "cornflour" "sunflower oil" "ginger" "garlic" "sherry" "red peppers" "carrots" "courgettes" "snow peas" "water chestnuts" "spring onion"] ["flour" "cooking oats" "brown sugar" "baking soda" "salt" "butter" "chocolate chips" "nuts" "caramel topping" "flour"]
# [0.13185887 0.         0.06062386 ... 0.09837179 0.06253255 0.06527592]
# ["lime jello" "boiling water" "milk" "horseradish" "lemon juice" "pineapple" "pecans" "cottage cheese" "mayonnaise"] ["apples" "cranberries" "sugar" "oats" "pecans" "brown sugar" "butter"] ["chicken broth" "carrots" "celery" "long-grain white rice" "chicken" "parsley flakes" "garlic"] ["shrimp" "tomato soup" "unflavored gelatin" "cold water" "cream cheese" "mayonnaise" "celery" "onion"]
# [0.08665971 0.13171817 0.1121989  ... 0.02330045 0.1170743  0.07926228]
# ["Shrimp" "tomato sauce" "tomato soup" "Tomato paste" "tomatoes" "onions" "Garlic" "zucchini" "Green pepper"]
# [0.         0.07873806 0.08331409 ... 0.03627329 0.00849064 0.35855763]
# ["leeks" "onion" "butter" "potatoes" "carrots" "salt" "rice" "stalks" "chopped spinach" "milk" "salt" "water"] ["tomato juice" "cucumbers" "tomatoes" "green pepper" "onion soup" "parsley" "olive oil" "Worcestershire sauce" "wine vinegar" "sherry wine" "Tabasco sauce" "Accent" "garlic powder" "celery salt" "salt" "turns pepper"]
# [0.05415612 0.04475845 0.17250356 ... 0.08063366 0.05283186 0.12914692]
# ["tomatillos" "white onion" "kosher salt" "sugar" "garlic" "serrano chile" "fresh cilantro"] ["flour" "white sugar" "cocoa" "baking soda" "water" "salad dressing" "vanilla"] ["black-eyed peas" "ham" "carrot" "onion" "salt"]
# [0.03820611 0.         0.05881408 ... 0.0752707  0.0586744  0.02323168]
# ["sugar" "all-purpose" "salad oil" "apples" "pecans" "eggs" "soda" "salt" "sour cream" "vanilla"] ["cauliflower" "broccoli" "green onions" "mayonnaise" "sour cream" "sugar" "celery" "pepper"] ["Lemon Juice" "Egg White" "Simple Syrup"] ["flour" "sugar" "baking soda" "salt" "mayonnaise" "mashed ripe bananas" "vanilla" "milk" "then" "peanut butter" "sugar" "vanilla" "milk" "milk chocolate chips"]
# [0.11921166 0.1455831  0.1057165  ... 0.04551552 0.10971567 0.05859221]
# ["red peppers" "snow peas" "Italian salad seasoning" "ginger" "Bermuda onion" "tomatoes" "soy sauce"] ["avocado" "lime juice" "lime zest" "salt" "pepper" "black beans" "Tabasco" "red onion" "salsa" "sour cream" "tomato" "scallions" "tortilla chips"]
# [0.         0.0857438  0.06304705 ... 0.07328753 0.02403518 0.10934456]
# ["mushrooms" "red peppers" "corn niblets" "butter" "flour" "salt" "pepper" "paprika" "chicken broth" "lemon juice" "milk" "chicken" "flour" "baking powder" "salt" "sage" "cumin" "shortening" "milk" "light corn syrup" "water"]
# [0.04941486 0.07187971 0.29124497 ... 0.01750942 0.03982591 0.07072588]
# ["corn bread dressing" "chicken" "cream of mushroom soup" "cream of chicken soup" "margarine"] ["maraschino cherry juice" "water" "currant jelly" "cornstarch" "rice wine vinegar"]
# [0.03718024 0.46913559 0.14102811 ... 0.         0.03770012 0.02896299]
# ["cereal" "boiling water" "sugar" "oil" "salt" "buttermilk" "whole wheat flour" "bran" "eggs" "soda"]
# [0.01476936 0.         0.02251083 ... 0.0366229  0.05087501 0.00889182]
# ["white bread" "butter" "Salt" "Vanilla" "brown sugar" "Egg" "Egg yolk"]
# [0.14164901 0.         0.08083048 ... 0.07872734 0.06847015 0.14589992]
# ["golden raisins" "wine" "bread" "butter" "milk" "cream" "vanilla pod" "sugar" "egg yolks" "brown sugar"] ["ground turkey" "garlic" "onion" "pepper" "garam masala" "paprika" "cumin" "coriander" "ginger" "curry" "tomatoes" "chicken broth" "frozen spinach" "sour cream" "egg noodles"] ["oleo" "whole kernel corn" "cream-style corn" "sour cream" "corn muffin" "grated cheese"]
# [0.06592127 0.2250365  0.3851687  ... 0.         0.07371077 0.12427004]
# ["potatoes" "margarine" "pineapple" "orange juice" "salt"] ["boiling water" "oatmeal" "bran cereal" "Shredded Wheat" "shortening" "eggs" "honey" "sugar" "sugar" "salt" "soda" "buttermilk" "flour"]
# [0.10786333 0.         0.0339056  ... 0.01955576 0.03320534 0.01339278]
# ["grouper" "mushrooms" "bay leaf" "white wine" "Salt" "butter" "onions" "bread crumbs" "thyme"] ["mustard" "water" "light" "plum sauce" "rice wine" "soy sauce" "sesame oil" "shrimp" "bacon"]
# [0.05006946 0.         0.03993636 ... 0.29674756 0.12240083 0.15382788]
# ["jello" "boiling water" "sugar" "warm water" "lemon juice" "pineapple juice" "ginger ale"] ["catsup" "chili sauce" "brown sugar" "mustard" "Worcestershire sauce" "garlic" "lemon slices"] ["lean ground beef" "onion" "American cheese" "Parmesan cheese" "salt" "garlic salt" "egg" "flour" "water" "salt" "paprika" "vegetable oil"]
# [0.03927401 0.04303491 0.14043484 ... 0.07810727 0.09485695 0.11429855]
# ["Chicken" "Salt" "wine" "Soy sauce" "Chicken" "Sesame oil" "Egg" "Flour" "adjust" "Vegetable oil"] ["deer meat" "olive oil" "onion" "green pepper" "clove garlic" "salt" "flour" "tomatoes" "red chili powder" "paprika" "cumin powder" "cloves" "bay leaf" "water" "yellow cornmeal"] ["onion" "celery" "clove garlic" "vegetable oil" "tomatoes" "tomato sauce" "sugar" "fresh parsley" "chili powder" "Worcestershire sauce" "Tabasco sauce" "cornstarch" "cold water" "salt" "shrimp" "green pepper"] ["clove garlic" "vegetable oil" "parsley" "salt" "lemon juice" "pepper" "flank steak" "Mushroom Sauce"]
# [0.00495475 0.07433823 0.19095278 ... 0.22255204 0.08083894 0.16555319]
# ["Butter" "Sugar" "Cocoa" "\u00bc" "Vanilla" "Eggs" "All-purpose" "Peanut Butter"]
# [0.11569733 0.         0.10473494 ... 0.         0.13249693 0.        ]
# ["pita bread" "store-bought" "mozzarella cheese" "your favorite Italian spices"] ["red wine vinegar" "water" "onions" "lemon" "cloves" "juniper berries" "bay leaves" "peppercorns" "salt" "sugar" "beef rump" "fat" "butter" "flour" "sugar"] ["water" "vinegar" "cornstarch" "sugar" "beets"] ["mangoes" "Kosher salt" "Cayenne pepper" "Extra-virgin olive oil" "lime" "crema" "peppers"]
# [0.02654746 0.03215004 0.07039467 ... 0.02042753 0.11826658 0.05202386]
# ["pepper" "red onion" "pork" "whole kernel corn" "white beans" "black beans" "tomatoes" "chili powder"] ["fresh basil" "chicken broth" "Parmesan cheese" "extra-virgin olive oil" "salt" "garlic" "cod fillet" "black pepper"] ["ground beef" "onion soup mix" "potatoes" "golden mushroom soup" "Cheddar cheese" "bread crumbs" "butter"] ["chocolate" "eggs" "butter" "powdered sugar" "pecans" "cream cheese"] ["orange juice" "lime juice" "garlic" "rum" "ground coriander" "salt" "white pepper" "pepper" "cayenne pepper" "pork shoulder roast" "olive oil" "loaves" "Yellow mustard" "dill" "deli ham" "Swiss cheese"]
# [0.01983891 0.17711943 0.30488146 ... 0.06029418 0.15280472 0.14063353]
# ["butter" "vanilla" "sugar" "eggs" "cake flour" "baking powder" "milk"] ["vegetable oil" "onions" "ginger garlic" "bay leaf" "potatoes" "frozen peas" "tomato puree" "garam masala" "paprika" "white sugar" "salt" "cilantro"] ["chicken breasts" "tomatoes" "onion" "garlic" "cannellini beans" "water"] ["coriander seeds" "cumin seeds" "unsweetened coconut milk" "curry powder" "hot chilies" "dry mustard" "salt" "bluefish fillet" "beans" "water"] ["Duncan" "water" "vegetable oil" "eggs" "condensed milk" "lemon juice"]
# [0.06318773 0.06927007 0.18298716 ... 0.12453317 0.18666395 0.10751023]
# ["mussels" "unsalted butter" "extra-virgin olive oil" "shallots" "garlic" "red pepper" "clams" "tarragon" "thyme" "rosemary" "white wine" "fettucine" "Salt" "Freshly ground black pepper" "parsley" "tarragon" "Parmesan"] ["cheddar cheese" "flour" "garlic" "dill weed" "oregano" "salt" "butter" "water"] ["mandarin oranges" "water" "sugar" "eggs" "almond meal" "baking powder"] ["flour" "salt" "baking powder" "butter" "milk" "fresh blueberries"] ["crabmeat" "celery" "fresh chives" "mayonnaise" "egg" "mustard" "hot sauce" "breadcrumbs" "Pepper" "mayonnaise" "red pepper" "fresh chives" "lemon juice" "garlic" "fresh chives"]
# [0.03499925 0.         0.23447713 ... 0.05130226 0.13599793 0.1338378 ]
# ["Cooking spray" "old-fashioned" "crispy wheat cereal squares" "brown sugar" "pecans" "salt" "ground cinnamon" "honey" "canola oil" "vanilla" "chocolate" "cranberries"] ["salt" "pepper" "butter" "mustard" "lemon juice" "Worcestershire sauce" "garlic" "breadcrumb"] ["sesame seeds" "flour" "ground cumin" "chili powder" "chickpeas" "eggs" "oil" "tomato sauce" "cheddar cheese" "spring onions"] ["flour" "sugar" "soda" "shortening" "buttermilk" "yeast" "butter" "cinnamon" "sugar"]
# [0.06907394 0.         0.14351776 ... 0.20422704 0.14962639 0.11288106]
# ["sugar" "eggs" "buttermilk" "Angel" "Crisco" "flour" "coconut flavoring"] ["PHILADELPHIA Cream Cheese" "Mayonnaise" "Pasta Sauce" "OSCAR MAYER Pepperoni" "green peppers" "Italian"] ["flour" "eggs" "pineapple" "walnuts" "baking soda" "sugar" "vanilla"] ["margarine" "brown sugar" "pineapple" "white cake"] ["Bread" "Whole wheat flour" "Brown sugar" "Shortening" "Salt" "Water" "Walnuts" "chestnuts" "raisins" "yeast" "Joshinko" "them"]
# [0.06944515 0.02944028 0.04650151 ... 0.03977532 0.03277313 0.03920318]
# ["egg" "olives" "parsley" "oregano" "mayonnaise"] ["boneless beef chuck roast" "onions" "butter" "apple juice" "catsup" "salt" "pepper" "thyme" "mustard" "basil" "sweet potatoes" "lemon juice" "apple ring" "parsley" "gravy"]
# [0.01170985 0.04534843 0.06021813 ... 0.00754142 0.15851322 0.0316168 ]
# ["chocolate" "orange juice" "butter" "sugar"] ["olive oil" "sweet onions" "garlic" "light rum" "mint" "sugar" "mayonnaise" "salt"] ["chicken" "chick-peas" "butter" "black pepper" "cinnamon" "tomato puree" "onions" "garlic" "hanout spice mix" "salt" "eggs" "chicken" "olive oil"] ["milk" "ground beef" "chili powder" "ground cumin" "oregano" "crescent roll" "cheddar cheese"]
# [0.04746581 0.09091074 0.18544036 ... 0.03605718 0.07367777 0.11980099]
# ["ground beef" "American cheese" "iceberg lettuce" "green onion" "sesame seeds"] ["sugar" "butter" "marshmallow cream" "milk" "chocolate chips" "nut meats" "vanilla"] ["cucumbers" "canning salt" "onions" "vinegar" "sugar" "celery" "ginger" "turmeric"] ["butter" "confectioners sugar" "vanilla flavoring" "almond flavoring" "lemon flavoring" "eggs" "flour"] ["ready"]
# [0.0742936  0.06479042 0.083141   ... 0.13961575 0.08011034 0.03010763]
# ["pork" "tofu" "clove Garlic" "Salt" "Black pepper" "Nutmeg" "leaves"] ["sugar" "butter" "milk" "yeast" "bread improver" "lemon" "salt" "chocolate chips" "CUSTARD" "milk" "custard powder" "sugar"] ["ground beef" "water" "tomato sauce" "yellow mustard" "onion powder" "garlic"] ["coconut oil" "onion" "clove garlic" "dried lentils" "chicken broth" "chili powder" "ground cumin" "oregano" "salt" "black beans" "corn kernels" "salsa" "shredded Monterey Jack cheese" "tortilla chips"]
# [0.08065823 0.04894156 0.24776338 ... 0.03805304 0.1113932  0.13543979]
# ["dates" "water" "baking soda" "white sugar" "butter" "egg" "flour" "baking powder" "pecans" "brown sugar" "water" "dates"]
# [0.079009   0.         0.09337737 ... 0.04070211 0.06114619 0.02502492]
# ["shortening" "sugar" "brown sugar" "egg" "vanilla" "flour" "soda" "salt" "nuts" "semi-sweet chocolate"] ["pork sausage" "heavy whipping cream" "tomatoes" "tomato" "pasta" "parmesan cheese"] ["cookies" "vanilla instant pudding" "milk" "powdered sugar" "margarine" "cream cheese"]
# [0.15590679 0.09442978 0.13474082 ... 0.00831293 0.11146127 0.15876258]
# ["sweet potatoes" "brown sugar" "maple syrup" "butter" "granny smith apples" "cinnamon"] ["squares" "butter" "brown sugar" "eggs" "flour" "vanilla" "semi-sweet chocolate chips" "nuts"] ["pasta" "Olive oil" "Garlic" "Onion" "Salt" "Garlic" "tomatoes" "Zucchini"]
# [0.15019313 0.         0.11799141 ... 0.02176199 0.07207067 0.02821976]
# ["Pearl barley" "Butter" "Onion" "Chicken stock" "Scallions" "fresh parsley" "nuts"] ["parsnips" "salt" "baking potatoes" "butter" "pepper"]
# [0.09063553 0.0445868  0.11949061 ... 0.01086104 0.0263454  0.0213143 ]
# ["Bell Chalupa bread" "flour" "baking powder" "salt" "vegetable shortening" "milk" "oil" "Bell Chalupa Supreme filling" "ground beef" "flour" "chili powder" "paprika" "salt" "onion flakes" "water" "oil" "sour cream" "shredded lettuce" "cheddar cheese" "tomato"] ["garlic" "green onions" "pepper" "avocado" "lemon juice" "chili powder" "salt" "tomatoes"] ["beef" "Onion Soup Mix" "Campbell's cream"] ["pecans" "cream cheese" "milk" "beef" "green pepper" "butter" "onion" "garlic powder" "sour cream"]
# [0.06161923 0.25602471 0.28019998 ... 0.02841806 0.05470557 0.10804779]
# ["corn tortillas" "ground beef" "onion" "pepper" "garlic" "paprika" "garlic" "salt" "pepper" "taco seasoning" "black olives" "tomatoes" "Ricotta cheese" "egg" "cheese" "Cheddar cheese"] ["onions" "water" "flour" "egg" "milk" "sugar" "salt" "canola oil" "Additional oil"] ["frozen broccoli" "chicken breasts" "cream of chicken soup" "cream of mushroom soup" "shredded cheese" "onion" "sour cream" "mayonnaise" "rice" "bread"] ["Frozen Blueberries" "Blackberries" "Rolled Oats" "Oat Flour" "Almonds" "Coconut Sugar" "Cinnamon" "\u00bc" "Unsweetened Applesauce"] ["shrimps" "garlic" "oyster sauce" "sugar" "fish sauce" "chicken soup stock"]
# [0.08407068 0.4230011  0.35228724 ... 0.05298854 0.08883052 0.13222241]
# ["spinach" "hearts" "onion" "lite cream cheese" "lite mayonnaise" "salt" "Parmesan cheese" "paprika"]
# [0.         0.05338444 0.11672672 ... 0.00939918 0.01144667 0.03203706]
# ["Italian bread" "Muenster cheese" "onion" "oleo" "eggs" "milk" "prepared mustard"] ["banana" "cream" "dark rum" "vanilla vodka" "brown sugar"]
# [0.0839487  0.05407112 0.06890057 ... 0.         0.0507724  0.06056579]
# ["sugar" "nonfat dry milk" "nondairy creamer" "cocoa" "powdered instant coffee" "ground allspice" "cinnamon" "salt"] ["butter" "orange marmalade" "sugar" "orange"] ["Sugar" "Vegetable Oil" "Buttermilk" "Eggs" "White Vinegar" "Vanilla" "Flour" "Baking Soda" "Salt" "Cocoa" "_____" "FROSTING" "weight Cream Cheese" "Butter" "Confectioners Sugar" "Vanilla" "White Chocolate Chips" "Chocolate Chips"] ["flour" "ground ginger" "ground cinnamon" "ground cloves" "salt" "vegetable shortening" "light brown sugar" "baking soda" "warm water" "molasses"]
# [0.09152854 0.02751168 0.08947745 ... 0.05848788 0.08066785 0.05935704]
# ["cucumbers" "onions" "garlic" "bell peppers" "salt" "vinegar" "sugar" "turmeric"]
# [0.01852762 0.         0.08953074 ... 0.01628744 0.01416277 0.03536482]
# ["cottage cheese" "cream" "butter" "sugar" "eggs" "vanilla"] ["pork belly" "water" "salt" "sugar" "aromatics"]
# [0.0678086  0.06162242 0.13006464 ... 0.01084961 0.09721134 0.0222056 ]
# ["flour" "shortening" "brown sugar" "baking powder" "egg" "water" "vinegar"] ["black pepper" "red pepper" "salt" "brown sugar"] ["plain yogurt" "vanilla pudding" "mandarin oranges" "pineapple" "stripe cookies"] ["fluid Bourbon"]
# [0.08607385 0.         0.10452504 ... 0.00773875 0.05488687 0.06006238]
# ["extra-virgin olive oil" "onion" "clove garlic" "carrots" "tomato paste" "ground chile pepper" "salt" "water" "lentils" "salt" "Greek yogurt"] ["OREO Cookies" "Chocolate" "'S" "JET-PUFFED Miniature Marshmallows" "chocolate"]
# [0.         0.         0.07576835 ... 0.0276622  0.03468906 0.13104293]
# ["potatoes" "ground beef" "onion" "corn" "grated cheese"] ["cucumber" "tomatoes" "onion" "red wine vinegar" "water" "seasoning mix"] ["All-purpose" "Whole Wheat Flour" "Baking Powder" "Sugar" "Ground" "Eggs" "Buttermilk" "Vegetable Oil" "Banana" "Vanilla"]
# [0.0320373  0.05412094 0.16087014 ... 0.01638687 0.10242087 0.12221288]
# ["sour cream" "plain yogurt" "sugar" "vinegar" "fresh broccoli" "bacon" "onion" "raisins"]
# [0.01652461 0.17302382 0.05505237 ... 0.         0.01921658 0.        ]
# ["sugar" "flour" "cocoa" "baking soda" "salt" "milk" "unsalted butter" "eggs" "peppermint" "cream cheese" "powdered sugar" "unsalted butter"] ["corn" "cabbage" "sweet red pepper" "sweet green pepper" "water" "vinegar" "onions" "celery" "salt" "turmeric" "sugar"] ["squash" "carrots" "onion" "salt" "sour cream" "dressing" "cream of chicken soup" "butter"]
# [0.07208913 0.29174164 0.31823512 ... 0.02137736 0.10938934 0.07006677]
# ["sour cream" "mayo" "onion" "parsley" "Accent" "spinach" "dill weed" "bread"] ["flounder" "onion" "salt" "potatoes" "bacon strips"]
# [0.         0.11124497 0.051589   ... 0.00933983 0.01137439 0.03843234]
# ["rice" "cream of chicken soup" "cream of celery soup" "water" "chicken breasts"] ["flour" "salt" "baking powder" "baking soda" "sugar" "ground coriander" "butter" "egg" "buttermilk" "raisins"] ["white bread" "milk" "vegetable oil" "onions" "carrot" "apple" "cayenne" "ground coriander" "dry mustard" "turmeric" "ground cloves" "ground cinnamon" "ground cardamom" "ground lamb" "raisins" "mango" "apricot" "white wine vinegar" "salt" "eggs"] ["Frozen Rhodes Rolls" "brown sugar" "butterscotch cook" "sugar" "cinnamon" "butter" "pecans"] ["links" "bottles" "sweet onion" "sauerkraut" "mayonnaise" "chili sauce" "ketchup" "onion" "sweet pickle" "garlic" "pepper" "buns" "Swiss cheese"]
# [0.06746432 0.23423894 0.18381561 ... 0.05888083 0.16007647 0.10721702]
# ["sour cream" "mayonnaise" "onion" "dill weed" "garlic"] ["water" "active yeast" "flour" "pizza sauce" "onion" "favorite cheese"] ["chicken" "cracker crumbs" "celery" "mushroom soup" "milk"]
# [0.01922918 0.29594339 0.10339677 ... 0.02863573 0.023427   0.10385781]
# ["water" "salt" "egg noodles" "butter" "poppy seed"] ["white cake mix" "rolled oats" "butter" "egg" "cherry pie filling" "nuts" "brown sugar"]
# [0.12394291 0.         0.07583224 ... 0.04517283 0.05464045 0.05022835]
# ["potatoes" "carrots" "onion" "clove garlic" "eggs" "cooking oil" "salt" "parsley" "breadcrumbs" "powdered milk" "tasty cheese" "bacon" "margarine" "grated cheese"]
# [0.02155807 0.         0.13058425 ... 0.02972355 0.01869651 0.13442738]
# ["water" "apple cider" "bay leaves" "ground cloves" "ground allspice" "poultry seasoning" "whole allspice" "whole cloves" "black peppercorns" "kosher salt"] ["Sugar" "Celery" "Water" "milliliters" "Drops"] ["milk" "sugar" "unsalted butter" "cream of wheat" "cornstarch" "eggs" "pastry" "water" "sugar" "lemon juice"] ["ground hamburger" "mushrooms" "onion" "egg" "breadcrumbs" "salt" "pepper" "campbells beefy mushroom soup"]
# [0.03652438 0.14639883 0.07037205 ... 0.0104189  0.18952709 0.06198226]
# ["layer" "cream of coconut" "flaked coconut"]
# [0.         0.17317266 0.0519509  ... 0.         0.01145418 0.        ]
# ["duck breasts" "red wine vinegar" "olive oil" "bay leaf" "thyme" "shallots" "Salt" "fresh figs" "red wine" "arugula" "chestnuts"] ["black-eyed peas" "hominy" "Jalape\u00f1os" "picante" "Italian dressing" "onion"] ["beans" "avocado dip" "black olives" "green chilies" "taco seasoning mix" "sour cream" "tomatoes" "onion" "Cheddar cheese"] ["pears" "peaches" "pineapple" "bananas" "cherry pie filling"] ["olives" "anchovies" "lemon juice" "garlic" "pepper" "olive oil"]
# [0.         0.10290812 0.07684304 ... 0.0223349  0.08089766 0.07150237]
# ["onion" "serrano chiles" "tomatoes" "garlic" "kosher salt"]
# [0.         0.         0.09464399 ... 0.01721764 0.04807232 0.03738456]
# ["apple cider" "brown sugar" "whole cloves" "whole allspice" "cinnamon sticks" "salt" "ground nutmeg" "rum"] ["flour" "baking powder" "baking soda" "salt" "cinnamon" "ground cloves" "allspice" "ginger" "sugar" "eggs" "pumpkin" "vegetable oil" "All-Bran" "semi-sweet chocolate morsels"] ["Virginia ham" "mustard" "brown sugar" "bread crumbs" "paprika" "cloves" "Canada Dry ginger ale"] ["sugar" "milk" "dates" "butter" "nuts" "vanilla"] ["Chicken" "Sauce" "Egg Whites" "Hot Sauce" "Fiber Cereal" "Garlic" "Onion Powder" "Pepper" "Butter" "Wing Sauce" "Hot Sauce"]
# [0.09957249 0.01718342 0.11346278 ... 0.0670019  0.13630216 0.14179247]
# ["baking potatoes" "bacon" "butter" "onion" "fresh mushrooms" "red pepper" "garlic" "ground black pepper" "fresh chives" "salt" "sour cream" "Cheddar cheese" "bread crumbs"] ["fresh asparagus" "water" "butter" "mint" "salt" "lemon juice" "white pepper"] ["seedless raspberry jam" "white wine vinegar" "canola oil" "salt" "lemon-pepper seasoning" "cabbage" "red cabbage" "tomatoes" "avocado" "cucumber" "unsweetened raspberries" "green onion"] ["yellow cake mix" "orange jello" "lemon jello" "oil" "water" "eggs"] ["chicken" "water" "onions" "black pepper" "chicken bouillon" "rice"]
# [0.03597393 0.09640053 0.18401012 ... 0.06657234 0.08671952 0.12296088]
# ["sugar" "butter" "eggs" "molasses" "baking soda" "cinnamon" "ginger" "clove" "salt" "flour"] ["pasta shells" "mayonnaise" "Parmesan cheese" "buttermilk" "onion" "parsley" "fresh basil" "salt" "pepper" "shrimp" "frozen peas" "pimientos" "tomato" "green onions"] ["salmon" "salt" "Italian parsley" "chicken broth" "white wine" "extra-virgin olive oil" "garlic" "red pepper"] ["ground beef" "noodles" "mushrooms" "onion rings" "mushroom soup"]
# [0.01744475 0.16592354 0.21496838 ... 0.05477773 0.0545067  0.11752284]
# ["Peanut" "flour" "seafood seasoning" "baking soda" "Kosher salt" "bottles" "fluke fillets" "rolls" "Tartar Sauce" "Pickles" "tomatoes" "red onions" "mayonnaise" "shallot" "cornichons" "whole-grain mustard" "celery salt" "cayenne pepper" "malt vinegar" "Kosher salt"]
# [0.         0.         0.05202    ... 0.0372868  0.0973497  0.04754336]
# ["white cake mix" "flour" "oil" "frozen strawberries" "eggs" "strawberry" "water"] ["thyme" "olive oil" "kosher salt" "butternut squash" "garlic"] ["vegetable oil" "lime juice" "orange juice" "garlic" "red chili pepper" "orange zest" "lime zest" "salt" "center" "kirby cucumbers" "mint"] ["yellow onions" "sugar" "flour" "thyme" "salt" "freshly ground black pepper" "beef stew meat" "vegetable oil" "fresh parsley" "bacon"]
# [0.00613951 0.03245458 0.16434692 ... 0.07507357 0.12608032 0.08854157]
# ["salmon" "heavy cream" "dill" "Salt" "bacon" "frozen puff pastry" "egg yolk" "milk" "Lemon wedges"]
# [0.02104678 0.05843099 0.17260302 ... 0.0102877  0.05315072 0.04613889]
# ["tart apples" "handles" "butter" "brown sugar" "light corn syrup" "condensed milk" "vanilla"] ["lemon" "apricots" "sugar" "fresh ginger" "coriander seed" "hot chili flakes" "salt" "lemon juice"] ["lemon juiced" "butter" "dark brown sugar" "eggs" "flour" "baking powder" "ginger" "blackberries" "powdered sugar"] ["nectarines" "brown sugar" "cider vinegar" "ginger" "kosher salt" "onion" "mustard" "cinnamon" "ground cloves" "almonds"]
# [0.11710461 0.         0.12236364 ... 0.01022791 0.14104127 0.02432531]
# ["carrots" "bell pepper" "onion" "pimento" "cornbread mix" "cream of chicken soup" "oleo" "sour cream" "grated cheese" "salt" "pepper"] ["brown sugar" "butter" "light corn syrup" "eggs" "milk" "cinnamon strawberries peaches"]
# [0.07048014 0.31266142 0.27814094 ... 0.00886681 0.05459208 0.1105145 ]
# ["cabbage" "whole wheat bread" "oil" "onions" "tomatoes" "garlic" "green peppers" "water" "paprika" "parsley"] ["butter" "unsweetened chocolate" "sugar" "eggs" "vanilla" "salt" "shell"] ["beef tenderloin" "butter" "clove garlic" "beef broth" "fresh mushrooms" "red onion" "Bearnaise mix" "sour cream" "Rice"] ["crab-stir" "red onion" "radishes" "cheese" "frozen peas" "mayo" "chili sauce"] ["sweet onion" "beef broth" "balsamic vinegar" "worcestershire sauce" "soy sauce" "garlic" "honey" "cayenne pepper" "black pepper" "salt" "chuck roast"]
# [0.05497095 0.1487507  0.22722323 ... 0.09483307 0.0518375  0.11928605]
# ...
# [0.         0.07624185 0.24022577 ... 0.         0.03168478 0.07479504]
# ["chocolate" "margarine" "coconut" "milk" "eggs" "sugar" "unbaked pie shell"] ["drink mix" "sugar" "cinnamon" "instant tea" "cloves"] ["Yeast" "Sugar" "Salt" "\u00bc" "Milk" "\u00bc" "Egg" "Flour" "_____" "FILLING" "Butter" "Brown Sugar" "Ground Cinnamon" "\u00bc" "_____" "STREUSEL" "Flour" "Oats" "Brown Sugar" "Ground Cinnamon" "\u00bc" "Butter" "_____" "CREAM CHEESE FROSTING" "weight Cream Cheese" "Butter" "Vanilla" "Powdered Sugar" "Milk"] ["Pancake mix" "flour" "Oil" "Water" "Salt"] ["Cucumbers" "Salt" "Kitchen Shears" "Water" "Rice Vinegar" "Sugar"]
# [0.13237252 0.04697646 0.11879768 ... 0.01993592 0.09682445 0.06348827]
# ["crushed strawberries" "sugar" "powdered pectin" "water"] ["rhubarb" "rhubarb" "sugar" "heavy cream" "greek yogurt" "honey" "crumble" "butter" "sugar" "oats" "flour" "salt" "almond flour"] ["grill seasoning" "Moutarde" "red onion" "unsalted butter"] ["red potatoes" "tart apples" "bacon" "onions" "sugar" "cider vinegar" "salt"]
# [0.04233041 0.03140478 0.07348946 ... 0.01105862 0.12296505 0.0329113 ]
# ["crawfish tails" "butter" "onion" "garlic" "bell pepper" "egg noodles" "flour"] ["pasta shells" "fresh basil" "garlic" "Parmesan cheese" "olive oil" "ricotta cheese" "onion" "thyme" "bay leaf" "olive oil" "white beans" "balsamic vinegar" "salt" "tomatoes" "bread crumbs" "olive oil"] ["cake" "milk" "instant vanilla pudding" "vanilla ice cream" "strawberry jello" "water" "strawberries"] ["shortening" "sugar" "applesauce" "flour" "soda" "salt" "cinnamon" "nuts" "vanilla"]
# [0.09851568 0.0324525  0.1595862  ... 0.06336052 0.10361409 0.14618364]
# ["spaghetti" "ground beef" "onion" "green pepper" "spaghetti sauce" "pizza sauce" "Cheddar cheese" "Mozzarella cheese" "mushrooms"] ["bacon" "bread cubes" "milk" "eggs" "salt" "butter" "Swiss cheese" "butter" "bread crumbs"] ["eggs" "milk" "potatoes" "biscuit mix" "salt" "butter"] ["eggplant" "egg" "sour cream" "flour" "Italian seasoned breadcrumbs" "marinara sauce"]
# [0.05333845 0.10926379 0.18217668 ... 0.0679073  0.04460358 0.19253371]
# ["flour" "baking pwdr" "salt" "sugar" "margarine" "milk" "egg" "blueberries" "margarine" "flour" "sugar" "cinnamon"] ["corn" "onion" "celery" "butter" "parsley" "salt" "savory" "pepper" "sour cream" "lemon juice"] ["shortening" "sugar" "flour" "baking powder" "salt" "milk" "peaches"] ["rice" "Mozzarella cheese" "pepperoni" "tomato" "vegetables" "Italian salad dressing"] ["nonfat chicken" "noodles" "instant chicken" "soy sauce" "garlic" "onion powder" "spice powder" "ground cumin" "coriander" "sugar substitute" "salt" "celery"]
# [0.08019917 0.11054497 0.27041921 ... 0.07241297 0.09493365 0.12469376]
# ["milk" "Almonds" "water"]
# [0.06514149 0.         0.         ... 0.         0.02889411 0.0499921 ]
# ["carrots" "cauliflower" "Salt" "sherry vinegar" "extra virgin olive oil" "fresh mint"]
# [0.         0.         0.0245832  ... 0.03999444 0.02515704 0.00971041]
# ["cumin" "onion powder" "garlic" "ground ginger" "paprika" "oregano" "mustard" "parsley flakes" "cayenne pepper"] ["mango" "black beans" "red onion" "cilantro" "lime juice" "salt" "buns"]
# [0.         0.         0.14137912 ... 0.01007303 0.07582667 0.07612222]
# ["unsalted butter" "sugar" "salt" "orange" "vanilla extract" "egg yolk" "flour" "raspberry"] ["pork roast" "onions" "thyme" "ground Jamaican allspice" "ground nutmeg" "ground cinnamon" "hot pepper" "soy sauce" "vegetable oil"] ["pastry sheet" "egg yolks" "white sugar" "milk" "vanilla" "chocolate chips" "handful" "handful of pomegranate seeds"] ["Dream Whip topping mix" "cold milk" "vanilla" "pie shell"] ["red wine vinegar" "maple syrup" "mustard" "tarragon" "kosher salt" "fresh ground pepper" "blackberry jam" "blended oil"]
# [0.0682779  0.03126253 0.05824053 ... 0.11699821 0.18319418 0.10417871]
# ["mushrooms" "mushrooms" "chicken broth" "balsamic vinegar"] ["butter" "lemon zest" "sugar" "flour" "cornstarch" "peel"]
# [0.03321762 0.05068808 0.03724893 ... 0.         0.02348259 0.        ]
# ["butter" "sugar" "egg yolks" "flour" "green tea" "white chocolate"] ["butter" "shallot" "red wine" "bay leaves" "fish stock" "salt" "black pepper" "fresh parsley"] ["milk" "raisins" "sugar" "vanilla extract" "ground nutmeg" "rice"] ["chicken" "butter" "salt" "red bell pepper" "yogurt" "cream cheese" "wisconsin gorgonzola" "green onions" "lemon-pepper seasoning" "salt"] ["rigatoni" "Italian sausage" "heavy cream" "pasta sauce" "Cajun spice" "celery" "red" "bell pepper" "clove garlic" "mexican cheese" "vegetable" "basil"]
# [0.08005394 0.07833291 0.23010334 ... 0.04899953 0.12011738 0.15846313]
# ["potatoes" "butter" "flour" "milk" "Velveeta cheese" "salt"]
# [0.08050098 0.         0.18339658 ... 0.02237035 0.04019567 0.08090715]
# ["ground venison" "ketchup" "water" "yellow mustard" "white vinegar" "sugar" "salt" "buns"] ["Soybean oil" "White vinegar" "Tomato paste" "Soy sauce" "Salt" "ginger" "Celery" "Onions"] ["sour cream" "flour" "butter" "eggs" "salt"] ["graham cracker crumbs" "butter" "cream cheese" "vanilla" "lemon juice" "liter" "pineapple"] ["tuna" "stock" "Black pepper" "nutmeg" "tomato sauce" "oregano" "Lemon" "fresh parsley"]
# [0.0405552  0.10703371 0.1551396  ... 0.14786965 0.09023544 0.20648876]
# ["zucchini" "water" "salt" "sugar" "oregano" "butter" "onions" "flour" "warm milk" "salt" "parmesan cheese"] ["lean ground beef" "egg" "parmesan cheese" "mustard" "ketchup" "basil" "parsley" "oregano" "thyme" "salt" "black pepper" "garlic" "green bell pepper" "onion" "pizza sauce" "mozzarella cheese"]
# [0.03707985 0.04707893 0.22542632 ... 0.04733999 0.12127955 0.14002561]
# ["sour cream" "onion flakes"] ["tightly packed torn romaine lettuce" "tomatoes" "whole wheat rotini pasta" "Milk" "cucumbers" "Ham" "Bacon" "Italian Dressing"] ["chicken pieces" "peach" "onion soup" "dressing"] ["Chicken" "weight Cream Cheese" "Dressing" "Celery" "Cheddar Cheese"] ["avocado" "honey"]
# [0.01178165 0.18666954 0.08335878 ... 0.         0.00962392 0.02472688]
# ["crescent rolls" "peanut butter" "butter" "dish of sugar" "cinnamon"] ["chocolate syrup" "heavy cream" "ground cinnamon" "sugar" "nutmeg" "coffee" "cream"]
# [0.05283839 0.17983264 0.13368362 ... 0.         0.10550522 0.01784251]
# ["extra-virgin olive oil" "yellow onion" "carrots" "Freshly ground black pepper" "chicken broth" "chicken" "peas" "oregano" "thyme" "parsley" "parmesan cheese"]
# [0.         0.09381619 0.07635252 ... 0.02080429 0.10957841 0.10478914]
# ["pork chops" "salt" "beans" "Kitchen" "water"] ["bread" "extra-virgin olive oil" "bacon" "mayonnaise" "salmon" "lemon juice" "Salt"] ["yellow cake mix" "eggs" "butter" "powdered sugar" "eggs" "lemon juice" "Philadelphia cream cheese"] ["ground beef" "tomatoes" "tomato sauce" "kidney beans" "brown gravy" "water" "bouillon" "bay leaves" "basil" "sugar" "brown sugar" "Worcestershire sauce" "green pepper" "head cabbage" "onion" "salt"] ["balsamic vinegar" "shallot" "salt" "figs" "mint leaves" "rosemary"]
# [0.06064303 0.06225225 0.10873437 ... 0.06342859 0.15109055 0.11370064]
# ["chicken" "Salt" "flour" "unsalted butter" "extra-virgin olive oil" "garlic" "carrots" "Cotes-" "bay leaf" "thyme" "rosemary" "prunes" "chicken stock"] ["blackberry" "raspberries" "sour mix" "triple sec" "tequila" "sugar" "lime slice"] ["sugar" "cocoa" "vanilla" "peanut butter" "margarine" "milk" "oats"]
# [0.05910202 0.08666602 0.06919623 ... 0.01692752 0.07635765 0.05525307]
# ["low-fat buttermilk" "salt" "salt" "breadcrumbs" "chicken" "chicken" "cooking spray"]
# [0.         0.10873312 0.04592232 ... 0.02648666 0.01012499 0.01813941]
# ["semi-sweet chocolate chips" "marshmallow cream" "pecans" "vanilla" "sugar" "margarine" "salt" "milk"] ["sausage" "white bread" "Cheddar cheese" "eggs" "milk" "salt" "dry mustard" "green chillies"] ["cornmeal" "full-fat coconut milk" "water" "sugar" "salt" "peaches" "oil" "coconut"] ["flour" "baking powder" "baking soda" "salt" "butter" "brown sugar" "honey" "almond" "eggs" "milk" "chocolate bits" "brown sugar" "all-purpose" "butter" "almonds" "butter" "milk"]
# [0.15479647 0.03108366 0.15612147 ... 0.05170491 0.1049879  0.11335946]
# ["white Karo" "brown sugar" "salt" "butter" "soda" "popcorn"] ["pkt Buckwheat pancake mix" "Molasses" "corn" "water" "Sugar" "Apple" "Cinnamon" "Egg"] ["flour" "fresh mushrooms" "mushroom soup" "curry" "water" "salt" "butter"] ["radish" "onion" "whole allspice" "whole cloves" "mustard seeds" "white vinegar" "sugar" "salt" "water"] ["pumpkin" "salt" "water"]
# [0.05501271 0.08745829 0.12489063 ... 0.22511178 0.16932498 0.02809426]
# ["extra-virgin olive oil" "garlic" "red pepper" "rice" "saffron threads" "bay leaf" "thyme" "fish" "casing chorizo" "onion" "red bell pepper" "shrimp" "white fish" "mussels" "peas" "lemon zested" "parsley" "lemon"] ["unflavored gelatin" "cold water" "apple cider" "sugar" "lemon juice" "ground cloves" "salt" "unpeeled apples" "walnuts" "celery" "sour cream" "mayonnaise" "sugar" "Ground cinnamon" "Cinnamon"] ["broccoli" "mayonnaise" "green onion" "olives" "eggs" "salt"] ["yellow cake mix" "egg" "margarine" "corn syrup" "brown sugar" "eggs" "vanilla" "pecans"]
# [0.0629118  0.05571018 0.12446939 ... 0.03483478 0.16730431 0.09973502]
# ["mayonnaise" "white wine" "garlic" "mustard" "paprika" "celery" "sugar" "rosemary" "poultry seasoning" "Worcestershire sauce" "tarragon vinegar" "steak sauce" "bitters" "liquid warm pepper sauce"] ["bread crumbs" "butter" "potatoes" "turkey" "egg"] ["olive oil" "salt" "green beans" "Olive oil" "lemon juice" "olive oil" "salt" "Tomato Salsa" "tomatoes" "capers" "red onion" "garlic" "flat leaf parsley" "balsamic vinegar" "olive oil" "red pepper" "cucumber" "salt"]
# [0.01479579 0.         0.12216674 ... 0.12676625 0.08001281 0.27250978]
# ["pecans" "flour" "salt" "unsalted butter" "water" "onion" "lump crabmeat" "cream cheese" "cream cheese" "eggs" "salt" "hot sauce" "shallots" "mushrooms" "lemon juice" "Worcestershire sauce" "hot sauce" "heavy whipping cream" "unsalted butter" "salt"] ["mushrooms" "frozen spinach" "Parmesan cheese" "Feta cheese" "green onions" "parsley" "salt"] ["flour" "sugar" "salt" "cold unsalted butter" "flour" "chamomile" "eggs" "sugar" "salt"]
# [0.03717675 0.09136455 0.29956186 ... 0.08118043 0.13582076 0.08480517]
# ["lamb" "vegetable stock cube" "olive oil" "garlic" "thyme" "sage" "handful fresh parsley" "rosemary" "gravy pot"] ["flour" "sugar" "ground cinnamon" "applesauce" "milk" "vegetable oil" "lemon juice" "vanilla" "butter" "egg" "apples"] ["Water" "Sugar" "Yeast" "Flour" "Salt" "Olive Oil" "Rosemary" "Kosher Salt"]
# [0.05485648 0.         0.06776304 ... 0.04934439 0.13621704 0.05602941]
# ["carrots" "celery" "onion" "flour" "mustard" "tomatoes" "salt" "Worcestershire sauce" "butter" "oil" "brown sugar"] ["butter" "onion" "green bell pepper" "stalks celery" "garlic" "tomato paste" "bay leaves" "Worcestershire sauce" "tomatoes" "chicken stock" "ham" "cooked andouille sausage" "chicken" "frozen cooked shrimp" "long-grain white rice"] ["ground turkey" "onion" "green bell pepper" "tomatoes" "chili beans" "kidney beans" "pinto beans" "black beans" "pepper" "garlic" "chili powder" "molasses" "ground cumin" "onion" "oregano" "salt" "cayenne pepper"]
# [0.05351704 0.03705216 0.20995121 ... 0.06110754 0.12330503 0.15677857]
# ["skinless" "butter" "garlic" "lemon juice" "condensed cream" "Italian seasoning" "Parmesan cheese" "cans spinach" "mushrooms" "bacon bits" "mozzarella cheese"] ["onion" "green pepper" "garlic" "canola oil" "chicken breasts" "beans" "garbanzo beans" "tomatoes" "sage" "ground cumin" "Salt"] ["bread" "sugar" "cinnamon" "oleo" "brown sugar"] ["olive oil" "red wine vinegar" "maple syrup" "brown mustard" "lime" "red pepper" "fresh ground black pepper" "salt"] ["chicken breasts" "flour" "egg" "Italian seasoned breadcrumbs" "butter" "olive oil" "avocado" "tomatoes" "deli" "swiss cheese"]
# [0.05799523 0.1613189  0.20073712 ... 0.03665694 0.10407282 0.12839619]
# ["sugar" "syrup" "butter" "vanilla" "peanut butter" "Toasties"] ["Ground Beef" "Ketchup" "Pickle Relish" "Chili Powder"]
# [0.06756138 0.06095415 0.11492535 ... 0.         0.02870416 0.01841737]
# ["beets" "honey" "port wine" "orange juice" "balsamic vinegar" "thyme" "mustard"] ["chicken broth" "water" "parsley" "garlic" "onion" "carrot" "skinless" "Spanish chorizo" "cubed red potato" "onion" "red bell pepper" "fresh garlic" "ground cumin" "kosher salt" "saffron threads" "sherry vinegar" "parsley"] ["banana" "milk" "sugar" "ground cinnamon" "almond"]
# [0.01913904 0.02468137 0.07511946 ... 0.00601222 0.08954996 0.08850976]
# ["cookies" "cream cheese" "instant vanilla pudding"] ["ground sirlion" "tomato sauce" "mushrooms" "mushroom soup" "green pepper" "onion" "spagetti" "butter" "Salt" "spray"] ["ground beef" "onion" "cream soup"] ["lobsters" "corn" "beans" "butter" "heavy cream" "ground cloves" "cayenne pepper" "Salt" "fresh chives"]
# [0.03416355 0.27896448 0.24666301 ... 0.0311911  0.07277148 0.1197916 ]
# ["unbuttered refrigerator" "vegetable oil"] ["Frozen Strawberries" "Sugar" "Cornstarch"] ["macaroni shells" "cucumber" "onion" "tomato" "sweet pickle relish" "eggs" "salad dressing" "salt" "pepper" "celery salt" "garlic salt"] ["tomatoes" "celery" "onions" "green peppers" "cinnamon sticks" "brown sugar" "cider vinegar" "salt" "mustard" "ground cloves"] ["flour" "baking powder" "eggs" "caster sugar" "salt" "vanilla pod" "oil" "milk" "raspberries" "cinnamon sugar" "pecan nuts" "double cream" "lemon balm" "paper"]
# [0.08452011 0.02747808 0.1742359  ... 0.04180674 0.11465441 0.0780513 ]
# ["Cocoa" "Sugar" "Ground Cinnamon" "Chocolate"] ["pineapple juice" "orange juice" "lemon juice" "sugar" "crushed ice" "milk" "whipped cream"]
# [0.046497   0.06111889 0.04078143 ... 0.         0.04680053 0.03644682]
# ["broccoli" "cream-style" "egg" "saltines" "onion" "butter" "salt" "pepper" "Monde"] ["milk" "sugar" "margarine" "vanilla" "marshmallow cream" "pecans"] ["Italian sausage" "garlic" "basil" "salt" "tomatoes" "tomato paste" "lasagna noodles" "fresh ricotta cheese" "parsley flakes" "eggs" "salt" "pepper" "mozzarella cheese"]
# [0.05152014 0.0817582  0.23697425 ... 0.02159224 0.04780048 0.2166476 ]
# ["flour" "salt" "baking soda" "butter" "sugar" "brown sugar" "eggs" "vanilla extract" "chocolate chips" "nuts"] ["water" "mushrooms" "onion soup" "sour cream" "flour"] ["yogurt" "curry" "chicken breasts" "lentils Spicy" "olive oil" "onion" "garlic" "cumin seeds" "red lentils" "tomatoes" "chicken stock" "cilantro"] ["egg" "ground beef" "green pepper" "onion" "salt" "cheese" "Worcestershire sauce" "sugar" "tomato sauce with" "pepper"] ["green beans" "tomatoes" "black olives" "extra virgin olive oil" "Salt" "salmon fillet" "lemons" "basil" "anchovy" "clove of garlic" "salt" "egg yolk" "mustard" "extra virgin olive oil" "olive oil" "Lemon juice" "Salt"]
# [0.07093602 0.22022626 0.14742088 ... 0.11620799 0.14277296 0.13261893]
# ["hamburger" "taco seasoning mix" "water" "crescent rolls" "corn chips" "sour cream" "Cheddar cheese"]
# [0.         0.14276101 0.19608324 ... 0.         0.02089144 0.01632257]
# ["avocados" "mayonnaise" "lemon juice" "lump crabmeat" "fresh cilantro" "chives" "serrano pepper" "capers" "pepper" "pepper" "paprika" "Lemon wedges"]
# [0.         0.         0.08859594 ... 0.         0.01953371 0.03499557]
# ["ground beef" "onions" "carrots" "water" "tomato sauce" "salt" "parsley" "basil" "celery" "tomatoes" "kidney beans" "black pepper" "oregano" "cabbage" "green beans" "elbow macaroni"] ["lemon pepper" "marjoram" "basil" "thyme" "rosemary" "white wine" "water" "olive oil" "Italian salad dressing" "garlic" "lemon" "lemon zest" "potatoes"] ["natural-style peanut butter" "tomatoes" "chickpeas" "kale" "oil" "onions" "mushrooms"]
# [0.00908797 0.03519476 0.08769083 ... 0.066225   0.0698002  0.08889189]
# ["carrots" "green pepper" "onion" "celery" "tomato soup" "Crisco oil" "sugar" "vinegar" "mustard" "Worcestershire sauce"] ["eggs" "milk" "chocolate syrup" "whiskey" "instant coffee" "Coffee" "vanilla"]

# %%
# Assuming ingredient_sequences is your padded input for recipes
model.fit(ingredient_sequences_padded, similarity_scores, epochs=10, batch_size=32, validation_split=0.2)

# %% [markdown]
# ### Data Augmentation: Generating Additional Features
# To enhance the dataset and improve model performance, we will generate additional features such as ingredient frequency and procedure length.
#
# 1. Ingredient Frequency
# Calculate the frequency of each ingredient appearing in the dataset.
#
# 2. Procedure Length
# Calculate the length of each procedure in terms of the number of words.

# %%
# Import necessary libraries
from collections import Counter
# import numpy as np

# Generate Ingredient Frequency Feature

# Flatten the list of all ingredients to calculate frequency
all_ingredients = [ingredient for sublist in df['ingredients_tokenized'] for ingredient in sublist]
ingredient_freq = Counter(all_ingredients)

# Create a column for ingredient frequency
df['ingredient_frequency'] = df['ingredients_tokenized'].apply(lambda x: np.mean([ingredient_freq[ingredient] for ingredient in x]))

# Example of ingredient frequency
print("\nIngredient Frequency:\n", df[['ingredients_tokenized', 'ingredient_frequency']].head())

# # Generate Procedure Length Feature

# # Create a column for procedure length
# df['procedure_length'] = df['procedure_tokenized'].apply(len)

# # Example of procedure length
# print("\nProcedure Length:\n", df[['procedure_tokenized', 'procedure_length']].head())

# Additional Feature: Number of Ingredients

# Create a column for the number of ingredients
df['num_ingredients'] = df['ingredients_tokenized'].apply(len)

# Example of number of ingredients
print("\nNumber of Ingredients:\n", df[['ingredients_tokenized', 'num_ingredients']].head())

# Display the dataframe with the new features
print("\nDataframe with New Features:\n", df.head())

# %% [markdown]
# ### Embedding Representations with Pre-trained Models (Word2Vec and GloVe)
# Using pre-trained embeddings such as Word2Vec and GloVe for ingredients and procedures can significantly improve the performance of your machine learning models. These embeddings capture the semantic relationships between words, providing rich context that can help the model understand the ingredients and procedures better.

# %% [markdown]
# #### Load Pre-trained Word2Vec and GloVe Embeddings

# %%
# Import necessary libraries
import gensim.downloader as api
# import numpy as np

# Load pre-trained Word2Vec model (Google News vectors)
word2vec_model = api.load("word2vec-google-news-300")

# Load pre-trained GloVe model (Common Crawl vectors)
glove_vectors = api.load("glove-wiki-gigaword-300")

# Check the number of words in each model
print("Word2Vec model contains {} words".format(len(word2vec_model)))
print("GloVe model contains {} words".format(len(glove_vectors)))

# %% [markdown]
# #### Create Functions to Get Embeddings for Ingredients and Procedures

# %%
# Function to get the embedding for a list of words using a specified model
def get_embedding(words, model, embedding_dim=300):
    # Initialize a zero vector of size equal to the embedding dimension (300 in this case)
    embedding = np.zeros((embedding_dim,))
    count = 0
    for word in words:
        if word in model:
            embedding += model[word]  # Add the word vector to the embedding
            count += 1
    if count > 0:
        embedding /= count  # Average the word vectors if there are valid words in the list
    return embedding

# Apply the function to get embeddings for ingredients and procedures
df['ingredients_embedding_w2v'] = df['ingredients_tokenized'].apply(lambda x: get_embedding(x, word2vec_model))
df['procedure_embedding_w2v'] = df['procedure_tokenized'].apply(lambda x: get_embedding(x, word2vec_model))

df['ingredients_embedding_glove'] = df['ingredients_tokenized'].apply(lambda x: get_embedding(x, glove_vectors))
df['procedure_embedding_glove'] = df['procedure_tokenized'].apply(lambda x: get_embedding(x, glove_vectors))

# Example of embeddings
print("\nWord2Vec Embedding for Ingredients:\n", df['ingredients_embedding_w2v'].head())
print("\nWord2Vec Embedding for Procedures:\n", df['procedure_embedding_w2v'].head())
print("\nGloVe Embedding for Ingredients:\n", df['ingredients_embedding_glove'].head())
print("\nGloVe Embedding for Procedures:\n", df['procedure_embedding_glove'].head())

# %% [markdown]
# #### Model Architecture for Recipe Recommendations - LSTM

# %%
# Import necessary libraries
from keras.models import Model
from keras.layers import Input, LSTM, Dense, Embedding, Concatenate, Flatten
from keras.optimizers import Adam

# Define model parameters
embedding_dim = 300  # Dimensions of the pre-trained embeddings
lstm_units = 128  # Number of LSTM units
dense_units = 64  # Number of Dense layer units

# Define input layers
ingredients_input = Input(shape=(None, embedding_dim), name='ingredients_input')
procedure_input = Input(shape=(None, embedding_dim), name='procedure_input')

# LSTM layers
ingredients_lstm = LSTM(lstm_units, return_sequences=True)(ingredients_input)
procedure_lstm = LSTM(lstm_units, return_sequences=True)(procedure_input)

# Flatten the LSTM outputs
ingredients_flat = Flatten()(ingredients_lstm)
procedure_flat = Flatten()(procedure_lstm)

# Concatenate the LSTM outputs
concatenated = Concatenate()([ingredients_flat, procedure_flat])

# Dense layers
dense_1 = Dense(dense_units, activation='relu')(concatenated)
output = Dense(1, activation='sigmoid')(dense_1)

# Define the model
model = Model(inputs=[ingredients_input, procedure_input], outputs=output)

# Compile the model
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()

# %% [markdown]
# # **Analysis**

# %% [markdown]
# ## **Unique values for the sources**

# %%
df['source'].unique()
# Out:
# ['Gathered', 'Recipes1M']
# Categories (2, object): ['Gathered', 'Recipes1M']

# %% [markdown]
# ## **Unique values for the recipes**

# %%
unique_names = len(df['name'].unique())
number_entries = len(df)
number_entries_old = len(df_old)
display(Markdown(f'Number of all entries: {number_entries:.0f} vs Number of all entries before cleaning: {number_entries_old :.0f}'))
display(Markdown(f'Number of unique names: {unique_names :.0f}'))
# Out:
# Number of all entries: 2231142 vs Number of all entries before cleaning: 2231142
# Number of unique names: 1312871

# %% [markdown]
# ## Distribution of number ingridients by sources

# %%
average_n_ingridients = df.groupby('source')['n_NER'].mean()
fig, ax = plt.subplots(figsize=(6, 4))
ax.set_title('Distribution of number ingridients by sources')
average_n_ingridients.plot(kind='barh', stacked=False, ax=ax)
# Show the chart
plt.show()
# Out:
# C:\Users\batoo\AppData\Local\Temp\ipykernel_7704\2558380749.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_n_ingridients = df.groupby('source')['n_NER'].mean()

# %% [markdown]
# ## **Distribution of number procedure steps by sources**

# %%
average_n_procedures = df.groupby('source')['n_procedures'].mean()
fig, ax = plt.subplots(figsize=(6, 4))
ax.set_title('Distribution of number procedure steps by sources')
average_n_procedures.plot(kind='barh', stacked=False, ax=ax)
# Show the chart
plt.show()

# %% [markdown]
# ## Ingridients

# %%
NER_exploded = df.explode('NER')

# %% [markdown]
# ### **List of ingridients**

# %%
ingridients = NER_exploded['NER']

# %%
# get the unique values of the exploded column
unique_NER_values = NER_exploded['NER'].unique()

# %%
display(Markdown(f'Number of unique ingridients: {len(unique_NER_values) :.0f}'))
# Out:
# Number of unique ingridients: 2133496

# %%
print(unique_NER_values[:200])
# Out:
# ['["brown sugar", "milk", "vanilla", "nuts", "butter", "bite size shredded rice biscuits"]'
#  '["beef", "chicken breasts", "cream of mushroom soup", "sour cream"]'
#  '["frozen corn", "cream cheese", "butter", "garlic powder", "salt", "pepper"]'
#  '["chicken", "chicken gravy", "cream of mushroom soup", "shredded cheese"]'
#  '["peanut butter", "graham cracker crumbs", "butter", "powdered sugar", "chocolate chips"]'
#  '["baking potatoes", "extra lean ground beef", "butter", "milk", "salt", "pepper", "Cheddar cheese", "bacon", "green onion", "sour cream"]'
#  '["sugar", "butter", "egg", "buttermilk", "flour", "salt", "soda", "buttermilk", "rhubarb", "vanilla"]'
#  '["cream-style corn", "whole kernel corn", "crackers", "egg", "butter", "pepper"]'
#  '["tomatoes", "water", "onions", "Worcestershire sauce", "green peppers", "oil"]'
#  '["pineapple", "condensed milk", "lemons", "pecans", "graham cracker crusts"]'
#  '["dark sweet pitted cherries", "ginger ale", "flavor gelatin", "boiling water", "almond extract", "marshmallows"]'
#  '["powdered sugar", "butter", "peanut butter", "paraffin", "chocolate chips"]'
#  '["chicken", "flour", "barbecue sauce"]'
#  '["taco sauce", "sour cream", "cream cheese", "ground beef", "taco seasoning", "shredded lettuce", "tomato", "onion", "green pepper", "Cheddar cheese"]'
#  '["pie filling", "pineapple", "condensed milk", "lemon juice"]'
#  '["shell", "cleaned strawberries", "water", "cornstarch", "sugar", "salt", "strawberry jello"]'
#  '["chocolate fudge cake", "white cake", "Wesson oil"]'
#  '["broccoli", "bacon", "green onions", "raisins", "mayonnaise", "vinegar", "sugar"]'
#  '["frozen strawberries", "pineapple", "bananas", "pecans", "strawberry", "boiling water", "sour cream"]'
#  '["sugar", "shortening", "applesauce", "soda", "cinnamon", "flour", "raisins", "nuts"]'
#  '["sugar", "shortening", "eggs", "salt", "soda", "flour", "nuts", "bananas"]'
#  '["cake mix", "chocolate fudge pudding", "sour cream", "water", "Wesson oil", "eggs", "Frango"]'
#  '["vegetable oil", "soy sauce", "garlic"]'
#  '["tomatoes", "oil", "garlic", "tomato paste", "peppers", "sugar", "salt", "sweet basil", "oregano", "Italian seasoning"]'
#  '["ground beef", "tomato juice", "oats", "egg", "onion", "pepper", "salt"]'
#  '["steak", "ground black pepper", "ground white pepper", "vegetable oil", "bell peppers", "beef stock", "salt", "ground red pepper", "flour", "onions", "celery"]'
#  '["long", "cooking oil", "tomato sauce", "water", "brown sugar", "mustard", "Worcestershire sauce", "onion"]'
#  '["condensed milk", "semi-sweet chocolate chips", "unsweetened chocolate", "nuts", "vanilla"]'
#  '["Ground Beef", "taco seasoning", "beans", "onion", "salsa", "green peppers", "Tomato", "cheddar cheese", "sour cream"]'
#  '["milk", "sugar", "yeast", "salt", "Crisco oil", "flour"]'
#  '["peaches", "fruit cocktail", "pineapple", "fresh strawberries", "red apples", "yellow apples", "bananas", "white grapes", "purple grapes"]'
#  '["chicken cutlets", "oil", "red vinegar", "oregano", "garlic salt"]'
#  '["cherry pie mix", "deluxe white cake mix", "butter", "ground nuts"]'
#  '["eggs", "salt", "pepper", "potatoes", "Cheddar cheese", "green onions"]'
#  '["macaroni", "tuna", "pimentos", "onion"]'
#  '["hearts", "mayonnaise", "Parmesan cheese"]'
#  '["sour cream", "vegetable soup mix", "broccoli", "Cheddar cheese"]'
#  '["Salad Supreme", "Italian dressing"]'
#  '["pear halves", "lime gelatin", "cream cheese", "lemon yogurt"]'
#  '["watermelon rind", "sugar", "apple vinegar", "oil", "oil of cinnamon"]'
#  '["chicken", "potatoes", "onions", "corn", "English peas", "peas", "butter beans", "tomatoes", "tomato juice", "macaroni", "black pepper", "salt", "sugar"]'
#  '["butter", "sugar", "egg", "flour", "baking powder", "salt", "milk", "vanilla", "brown sugar", "cinnamon", "butter"]'
#  '["flour", "sugar", "baking powder", "yeast", "buttermilk", "soda", "margarine", "warm water"]'
#  '["marshmallows", "margarine", "peppermint candy", "crescent rolls"]'
#  '["yellow cake mix", "water", "brown sugar", "butter", "eggs", "nuts"]'
#  '["flour", "sugar", "oleo", "eggs", "chocolate syrup"]'
#  '["flour", "beer", "sugar"]'
#  '["margarine", "onion", "celery", "flour", "curry powder", "mushrooms", "cream of celery soup", "broccoli", "chicken", "cheese"]'
#  '["flour", "baking powder", "salt", "butter", "sugar", "egg yolks", "vanilla", "multi-colored candies"]'
#  '["ground beef", "water", "sugar", "onion soup", "tomatoes", "tomato sauce", "frozen mixed vegetables"]'
#  '["chicken breasts", "cream of chicken soup", "cream of mushroom soup", "green chili salsa sauce", "green chilies", "milk", "onion", "corn tortilla"]'
#  '["cabbage", "carrots", "green pepper", "onion", "mayonnaise", "vinegar", "sugar", "celery", "salt"]'
#  '["flounder", "tomatoes", "green pepper", "lemon juice", "salad oil", "salt", "onion", "basil", "ground black pepper", "drops red pepper sauce", "green pepper"]'
#  '["green beans", "yellow beans", "kidney beans", "sugar", "salad oil", "vinegar", "water"]'
#  '["whole kernel corn", "cream-style", "sour cream", "corn bread", "margarine"]'
#  '["ground beef", "onion", "tomato soup", "noodles", "oregano", "salt", "water", "cheese"]'
#  '["cabbage", "dry mustard", "corned beef", "cream of celery soup", "onion"]'
#  '["Worcestershire sauce", "dry mustard", "mayonnaise", "egg"]'
#  '["cream cheese", "mayonnaise", "taco sauce", "green onions", "green pepper", "tomato", "Mozzarella cheese", "Cheddar cheese", "black olives", "tortilla chips"]'
#  '["butter", "peanut butter", "graham cracker crumbs", "coconut", "nut meats", "vanilla"]'
#  '["orange sliced candy", "Angel", "pecans", "condensed milk", "vanilla", "orange flavoring"]'
#  '["yellow cake", "eggs", "oleo", "nuts", "eggs", "cream cheese", "powdered sugar"]'
#  '["pineapple", "bananas"]'
#  '["cream of mushroom soup", "cream of chicken soup", "cream of celery soup", "chicken", "butter", "rice"]'
#  '["cream cheese", "condensed milk", "pineapple", "nuts", "lemon juice"]'
#  '["vanilla", "cream cheese", "butter", "peanut butter"]'
#  '["peaches", "sugar", "sour cream", "lemon juice", "vanilla"]'
#  '["frozen strawberries", "sugar", "cream cheese"]'
#  '["margarine", "graham cracker crumbs", "granulated sugar"]'
#  '["flour", "baking soda", "salt", "shortening", "sugar", "eggs", "cocoa", "water", "vanilla", "milk"]'
#  '["apples", "raisins", "brown sugar", "sugar", "shortening", "cold water", "flour", "soda", "cinnamon", "nutmeg", "cloves", "salt", "nuts"]'
#  '["potatoes", "onion", "butter", "cream of chicken soup", "sour cream", "Cheddar cheese", "cornflakes"]'
#  '["vanilla wafers", "butter"]'
#  '["sugar", "white corn syrup", "cold water", "egg whites", "vanilla", "nuts"]'
#  '["apples", "sugar", "cinnamon", "sugar", "flour", "salt", "corn flake crumbs", "oleo"]'
#  '["Bisquick", "sausage", "Cheddar cheese"]'
#  '["chicken", "cream of chicken soup", "consomme", "rice", "salt", "pepper"]'
#  '["celery", "onions", "butter", "ground beef", "vinegar", "lemon juice", "brown sugar", "mustard", "salt", "pepper", "catsup", "water"]'
#  '["chicken broth", "cornstarch", "egg", "green onion"]'
#  '["apple juice", "allspice", "whole cloves", "cinnamon", "brown sugar"]'
#  '["sesame seed", "grated ginger", "honey", "soy sauce", "chicken", "vegetable cooking spray", "thin green onion strips"]'
#  '["Vidalia onion", "fresh mushrooms", "green peppers", "clove garlic", "olive oil", "bread", "eggs", "milk"]'
#  '["cranberries", "sugar", "apple", "orange", "orange gelatin", "nuts"]'
#  '["rice", "beef consomme", "onion soup", "mushrooms", "margarine"]'
#  '["cream cheese", "margarine", "sugar", "cranberry sauce", "pineapple", "walnuts", "whipping cream"]'
#  '["Velveeta cheese", "Italian tomatoes", "green chili peppers", "onion", "garlic", "salt"]'
#  '["flour", "salt", "soda", "sugar", "baking powder", "egg", "milk", "oil", "powdered sugar"]'
#  '["confectioners sugar", "cocoa", "nuts", "margarine", "Velveeta", "vanilla"]'
#  '["squash", "onions", "sour cream", "carrots", "chicken", "stuffing mix", "butter", "salt"]'
#  '["cream cheese", "Cheddar cheese", "pimento", "green pepper", "onion", "lemon juice", "Worcestershire sauce", "Tabasco sauce", "salt"]'
#  '["apricot jello", "sugar", "cream cheese", "jars Junior baby food", "pineapple", "milk", "water"]'
#  '["flour", "sugar", "baking powder", "salt", "eggs", "margarine", "butter", "sweet milk", "vanilla"]'
#  '["bread", "margarine", "brown sugar", "vanilla pudding", "milk", "cinnamon"]'
#  '["crescent rolls", "cheese", "hen", "cream of chicken soup", "milk"]'
#  '["Spanish rice", "corned beef", "onion", "Cheddar cheese"]'
#  '["pork", "bell pepper", "onions", "catsup", "brown sugar", "salt", "black pepper", "ground beef", "oil"]'
#  '["chicken", "shortening", "onion", "carrot chunks", "water", "chicken", "brown sugar", "cornstarch", "ginger", "catsup", "vinegar", "soy sauce", "green pepper", "pineapple"]'
#  '["oranges", "moist coconut", "pecans", "cherries", "sugar", "orange juice"]'
#  '["peanut butter", "sugar", "egg"]'
#  '["yellow cake mix", "eggs", "margarine", "milk", "pecans"]'
#  '["flour", "soda", "salt", "sugar", "egg", "margarine", "buttermilk"]'
#  '["butter", "mushrooms", "garlic", "zucchini", "onion", "eggs", "Ricotta cheese", "shredded Monterey Jack", "frozen spinach", "dill weed", "salt"]'
#  '["red cabbage", "butter", "apples", "brown sugar", "vinegar"]'
#  '["potatoes", "bacon", "sugar", "flour", "salt", "pepper", "cider vinegar", "water", "green onions"]'
#  '["butter", "onions", "ground beef", "clove garlic", "beef", "tomatoes", "potatoes", "carrots", "celery", "frozen green beans", "red wine", "basil", "thyme", "salt"]'
#  '["sugar", "sugar", "ground cloves", "cinnamon", "instant tea"]'
#  '["Manwich", "hamburg", "American cheese", "noodles"]'
#  '["shortening", "butter", "sugar", "eggs", "vanilla", "flour", "baking powder", "salt"]'
#  '["lime", "orange", "apple", "sugar", "red Spanish", "brandy", "Triple Sec", "club soda"]'
#  '["hamburger", "onion", "kidney beans", "butter beans", "beans", "ketchup", "green chilies", "mustard", "beef bouillon", "water", "honey", "bell pepper", "Worcestershire sauce", "garlic"]'
#  '["cooking oats", "brown sugar", "salad oil", "eggs", "salt", "almond extract"]'
#  '["Chinese noodles", "Campbell\'s cream", "water", "Chicken", "cashews", "celery", "onion", "peas", "soy sauce"]'
#  '["Cheddar cheese", "cream cheese", "ham", "pimiento", "parsley", "Worcestershire sauce", "onion"]'
#  '["cream cheese", "black olives", "Armour dried beef", "green onions", "mushrooms"]'
#  '["shells", "chicken", "broccoli flowerets", "cauliflower", "carrots", "green onions", "fresh mushrooms", "Italian salad dressing", "milk", "salt"]'
#  '["frozen artichoke", "water", "zucchini", "fresh mushrooms", "green onion", "garlic", "margarine", "tomatoes", "Parmesan cheese"]'
#  '["ground chuck", "shortening", "tomatoes", "tomato sauce", "salt", "sugar", "garlic", "egg noodles", "sour cream", "cream cheese", "green onions", "grated cheese"]'
#  '["chunk white chicken", "celery", "almonds", "water chestnuts", "white grapes", "salt", "pepper", "lemon juice", "curry powder", "nonfat mayonnaise"]'
#  '["margarine", "sugar", "meal", "vinegar", "eggs", "salt", "vanilla"]'
#  '["vermicelli", "bell pepper", "zucchini", "purple onion", "Salad Supreme seasoning"]'
#  '["cucumbers", "white vinegar", "salt", "sugar", "onion", "dill"]'
#  '["chicken", "cream of mushroom soup", "cream of chicken soup", "tomatoes", "your choice", "spaghetti", "steak seasoning"]'
#  '["cream cheese", "sharp cheese", "mayonnaise", "Worcestershire sauce", "garlic salt", "celery salt", "onion salt", "pimento", "olives", "parsley flakes", "beef"]'
#  '["pistachio pie filling", "pineapple", "marshmallows"]'
#  '["egg", "milk", "vegetable oil", "flour", "sugar", "baking powder", "salt", "blueberries"]'
#  '["flour", "margarine", "pecans", "cream cheese", "powdered sugar", "instant vanilla pudding", "milk"]'
#  '["water", "butter", "sugar", "flour", "eggs"]'
#  '["cream-style corn", "eggs", "onion", "crackers", "salt"]'
#  '["ground beef", "onion", "beans", "kidney beans", "yellow lima beans", "green baby", "brown sugar", "syrup", "chili powder", "ketchup", "mustard", "salt"]'
#  '["cake", "apricot nectar", "sugar", "cornstarch", "walnuts"]'
#  '["cake mix", "cream cheese", "alfalfa honey", "almonds"]'
#  '["rice", "onion soup", "cream of chicken", "mushrooms", "bite"]'
#  '["mayonnaise", "Romano cheese", "artichokes"]'
#  '["butter", "onions", "beef stock", "chicken stock", "Worcestershire sauce", "bay leaf", "garlic salt", "black pepper", "salt"]'
#  '["apples", "sugar", "flour", "cinnamon", "salt"]'
#  '["hamburger", "ketchup", "Worcestershire sauce", "mustard", "sugar", "salt"]'
#  '["flour", "sugar", "eggs", "butter", "lemon flavor", "yellow food coloring"]'
#  '["corned beef", "cream cheese", "mayonnaise", "pickles", "onion", "horseradish", "Worcestershire sauce", "pickle juice"]'
#  '["sugar", "milk", "cocoa", "flour", "egg yolks", "clump", "vanilla", "boiling water"]'
#  '["Tater", "ground beef", "onion", "bell pepper", "cream of mushroom soup", "cream of celery soup", "cream of chicken soup", "grated cheese"]'
#  '["sugar", "cornstarch", "water", "flavored gelatin", "fresh blackberries", "pastry shell"]'
#  '["coconut", "margarine", "slivered almonds", "milk", "graham cracker crusts", "cream cheese", "caramel topping"]'
#  '["Miracle", "sour cream", "onion", "parsley flakes", "dill weed"]'
#  '["onion", "oil", "frozen broccoli", "margarine", "mix", "eggs", "cottage cheese"]'
#  '["onion", "potato", "green sweet peppers", "celery", "carrots", "macaroni", "ground turkey", "beans", "bay leaf", "Italian seasoning", "sweet peas", "tomato juice"]'
#  '["cocoa", "oleo", "flour", "sugar", "baking soda", "salt", "eggs", "vanilla", "water", "buttermilk"]'
#  '["butter", "graham cracker crumbs", "milk", "semi-sweet chocolate chips", "flaked coconut", "nuts"]'
#  '["sugar", "brown sugar", "milk", "butter", "pecans", "coconut"]'
#  '["chocolate pudding", "vanilla wafers", "pecans"]'
#  '["white sugar", "butter", "milk", "chocolate chips", "vanilla"]'
#  '["unflavored gelatine", "milk", "eggs", "pumpkin", "cinnamon", "ginger", "salt", "pie shells"]'
#  '["eggs", "sugar", "ground nutmeg", "orange juice", "cream", "vanilla"]'
#  '["cereal", "chocolate chips", "powdered sugar", "peanut butter", "margarine", "vanilla"]'
#  '["yellow hominy", "olives", "green chilies", "tamales", "Cheddar cheese", "onions"]'
#  '["beans", "guacamole dip", "sour cream", "mayonnaise", "taco seasoning", "Mozzarella cheese", "cheddar cheese", "green onions"]'
#  '["water", "cake yeast", "salt", "eggs", "sugar"]'
#  '["chicken", "cream of mushroom soup", "chicken broth", "peas", "onion", "oleo", "milk", "baking powder", "flour"]'
#  '["chicken", "olive", "green onions", "clove garlic", "arborio", "oregano", "salt", "black pepper", "spinach", "parmesan cheese"]'
#  '["oil", "eggplant", "onions", "cauliflower", "green pepper", "fresh parsley", "mushrooms", "garlic", "Italian tomatoes", "bay leaf", "basil", "oregano", "thyme", "marjoram", "rosemary", "salt", "red"]'
#  '["white cake mix", "+", "pistachio instant pudding", "ginger ale", "eggs", "pecans", "cool whip", "milk", "pistachio instant pudding"]'
#  '["flour", "walnuts", "eggs", "sugar", "allspice", "oil"]'
#  '["cranberry juice", "ginger ale", "O", "boiling water", "frozen lemonade", "cold water"]'
#  '["sweet potatoes", "butter", "sugar", "eggs", "nutmeg"]'
#  '["sugar", "Crisco oil", "eggs", "flour", "sweet milk", "vanilla flavor", "butternut flavor"]'
#  '["flour", "sugar", "baking soda", "ground cinnamon", "salt", "carrots", "raisins", "coconut", "pecans", "pineapple", "vegetable oil", "eggs", "vanilla"]'
#  '["wild rice", "condensed cream", "onion soup", "mushrooms", "water", "chicken breasts", "butter", "cornflake crumbs"]'
#  '["green pepper", "onion", "bacon drippings", "flour", "salt", "sugar", "paprika", "tomatoes", "green peas"]'
#  '["eggs", "bananas", "butter", "sugar", "flour", "soda", "cream of tartar", "nuts"]'
#  '["Bisquick", "beef hash", "mustard", "salt"]'
#  '["hash browns", "margarine", "salt", "pepper", "onion", "cream of mushroom soup", "sour cream", "grated sharp"]'
#  '["flour", "baking powder", "sugar", "salt", "cream of tartar", "butter", "egg", "milk"]'
#  '["lean hamburger", "Ricotta cheese", "lasagne noodles", "Mozzarella cheese"]'
#  '["new potatoes", "onions", "stalks celery", "cider vinegar", "hot bacon", "bacon", "salt", "parsley"]'
#  '["eggs", "milk", "vanilla", "butter", "sugar", "flour", "coconut"]'
#  '["ground beef", "flour", "salt"]'
#  '["flour", "baking powder", "salt", "sugar", "egg", "milk", "butter"]'
#  '["egg", "light brown sugar", "vanilla", "pecans"]'
#  '["ground beef", "sauce", "Mozzarella cheese", "mushrooms", "biscuit mix", "milk", "eggs"]'
#  '["semi-sweet chocolate chips", "condensed milk", "chocolate wafers", "nuts"]'
#  '["broccoli", "mushroom soup", "mayonnaise", "egg", "onion", "salt"]'
#  '["flour", "baking powder", "almond extract", "nuts", "maraschino cherries", "sugar", "salt", "eggs", "dates", "semi-sweet chocolate chips"]'
#  '["hamburger", "oil", "onion", "celery", "rice", "cream of mushroom soup", "cream of chicken soup", "water", "soy sauce", "pepper", "noodles"]'
#  '["butter", "sugar", "water", "almonds", "chocolate", "almonds"]'
#  '["peppers", "onion", "garlic powder", "ground beef", "rice", "egg", "salt"]'
#  '["eggs", "yellow cake mix", "water", "oil"]'
#  '["butter", "peanut butter", "brown sugar", "white sugar", "egg", "vanilla", "flour", "baking soda", "salt", "butter"]'
#  '["eggs", "milk", "mustard", "salt", "onion powder", "pepper", "croutons"]'
#  '["margarine", "egg", "cinnamon", "ground cloves", "salt", "pecans", "brown sugar", "flour", "baking soda", "ground nutmeg", "raisins", "applesauce"]'
#  '["flour", "eggs", "water"]'
#  '["margarine", "milk", "sugar", "marshmallows", "baking chocolate", "milk chocolate", "semi-sweet chocolate", "vanilla", "nuts"]'
#  '["eggs", "flour", "salt", "sugar", "baking powder", "chocolate chips", "nuts", "candied cherries"]'
#  '["butter", "confectioners sugar"]'
#  '["all-purpose", "cocoa", "sugar", "eggs", "margarine", "salt", "vanilla", "nuts", "cream"]'
#  '["water", "margarine", "flour", "eggs", "vanilla instant pudding", "milk", "cream cheese", "chocolate syrup"]'
#  '["nonfat plain yogurt", "heavy cream", "mandarin juice"]'
#  '["cocoa", "butter", "powdered sugar", "milk", "vanilla", "peanut butter"]'
#  '["olive oil", "garlic powder", "bread", "thyme", "marjoram", "paprika", "Parmesan cheese"]'
#  '["pineapple", "mandarin oranges", "grapes", "marshmallows", "strawberries", "apples", "lemon juice", "orange juice", "cornstarch", "sugar", "bananas", "nuts"]'
#  '["strawberries", "water", "salt", "sugar", "cornstarch", "cinnamon", "butter"]'
#  '["sugar", "eggs", "milk", "cornstarch", "vanilla", "ground cinnamon", "pie shell"]']

# %% [markdown]
# There is an issue with the data, as it contains inconsistent naming conventions. For instance, "apples" should be "apple", and different types of cheese should be grouped into a single "cheese" category.

# %% [markdown]
# ### **World cloud of ingridients**

# %%
# Generate the word cloud
wordcloud = WordCloud(width=800, height=800, background_color='white').generate(' '.join(ingridients[:1000]))

# Display the word cloud using matplotlib
plt.figure(figsize=(8, 8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### **World cloud of unique ingridients**

# %%
# Generate the word cloud
wordcloud = WordCloud(width=800, height=800, background_color='white').generate(' '.join(unique_NER_values[:1000]))

# Display the word cloud using matplotlib
plt.figure(figsize=(8, 8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
